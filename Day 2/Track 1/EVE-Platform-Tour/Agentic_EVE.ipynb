# %% [markdown]
# # Building Agentic Earth Intelligence: A Hands-On Tour of the EVE Platform and Tool Ecosystem

# %% [markdown]
# ## The EVE project
#
# [Earth Virtual Expert (EVE)](https://eve.philab.esa.int/about) is a Φ-lab initiative advancing foundation models for Earth Observation and Earth Science. EVE is a domain-specialized large language model system built on an open-source foundation and fine-tuned on curated EO and Earth Science corpora. It integrates retrieval-augmented generation (RAG), structured citations, and hallucination-aware evaluation to provide grounded, traceable answers across heterogeneous knowledge sources. Deployed as a web platform and API, EVE enables natural-language interaction with scientific literature, institutional content, and technical documentation for reliable Earth Intelligence applications.
#
# ### The projects phasess
#
# - Project start: begin May 2025
# - Pilot Sept 2025-January 2026: ~350 user's testing and providing feedback to the platform
# - Open-sourcing: [here](https://huggingface.co/eve-esa) you can find: models, data, pipelines freely available for the community.
# - Begin second phase in Q2 2026: we will further develop the platform's capability providing Agentic capability, multimodal RAG and image reasoning.
#
# <img src="./images/timeline_full.png" alt="EVE's timeline" style="max-width: 1200px;" />
#
#
#
# ### Team & initiative
#
# The project is developed by **Pi School**, with support from **Imperative Space**, under **ESA Φ-lab**.
#
# <div style="contain:layout;overflow:hidden;margin:0;padding:0 0 1rem 0;">
# <div style="display:flex;flex-wrap:wrap;justify-content:center;align-items:center;gap:2rem;row-gap:1.25rem;margin:0.5rem 0 0 0;">
#
# <div style="flex:0 1 200px;text-align:center;min-width:0;">
#   <div style="padding:12px 16px;margin:0 auto;width:fit-content;max-width:100%;box-sizing:border-box;">
#     <img src="./images/ESAΦ-lab_DS.png" alt="ESA Φ-lab" style="width:250px;max-width:100%;height:auto;display:block;margin:0 auto;object-fit:contain;"/>
#   </div>
# </div>
#
# <div style="flex:0 1 200px;text-align:center;min-width:0;">
#   <img src="https://cdn.prod.website-files.com/66755cab0b1a9a549e0126ee/667d4707102098ff53e16b41_logo-pischool-colour.png" alt="Pi School" style="width:140px;max-width:100%;height:auto;display:block;margin:0 auto;object-fit:contain;"/>
# </div>
#
# <div style="flex:0 1 220px;text-align:center;min-width:0;">
#   <img src="https://cdn.prod.website-files.com/66755cab0b1a9a549e0126ee/670cf601867d52bac3b06b9a_ImperativeLogo-blue-1024px.png" alt="Imperative Space" style="width:150px;max-width:100%;height:auto;display:block;margin:0 auto;object-fit:contain;"/>
# </div>
#
#
# </div>
# </div>
#
# - **[ESA Φ-lab](https://philab.esa.int/)**: ESA Φ-lab accelerates the future of Earth Observation (EO) through disruptive/transformational innovations and commercialisation actions. The mission is to enhance the global competitiveness of the industrial and scientific sectors across ESA Member States.
# - **[Pi School](https://picampus-school.com/)**: Lead development and research. Pi School helps organisations achieve real business impact through applied research and practical training. Founded in 2017, Pi School draws on experience building AI for industry and contributes to EU-, ESA-, and institution-funded initiatives across sectors.
# - **[Imperative Space](https://imperative.space/)**: Communications, education and platform support. A multi-disciplinary media, education, communications, technology and innovation company working across the space sector, including Earth Observation, satcoms, exploration, and astronomy, with a mission to support sustainable development and the furthering of human knowledge.
#
# ### Partners
#
# <div style="contain:layout;overflow:hidden;margin:0;padding:0 0 1rem 0;">
# <div style="display:flex;flex-wrap:wrap;justify-content:center;align-items:center;gap:3rem;margin:0.5rem 0 0 0;">
#
# <div style="flex:0 1 280px;text-align:center;min-width:0;">
#   <img src="https://cdn.prod.website-files.com/66755cab0b1a9a549e0126ee/69aee8be9bb5491f851d8f57_mistral-logo-color-black.png" alt="Mistral AI" style="width:200px;max-width:100%;height:auto;display:block;margin:0 auto;object-fit:contain;"/>
# </div>
#
# <div style="flex:0 1 280px;text-align:center;min-width:0;">
#   <img src="https://cdn.prod.website-files.com/66755cab0b1a9a549e0126ee/69aeea29d5214ea9be0ac24c_aef83358a24c01e9dce91ec7ee4b8886_Wiley_Wordmark_black.png" alt="Wiley" style="width:200px;max-width:100%;height:auto;display:block;margin:0 auto;object-fit:contain;"/>
# </div>
#
# </div>
# </div>
#
# - **[Mistral AI](https://mistral.ai/)** — Open foundation models and infrastructure for generative AI. EVE is fine-tuned from Mistral Small.
# - **[Wiley](https://www.wiley.com/)** — Authoritative scientific publishing and research intelligence; partner for grounded, citation-aware Earth Science content.
#
# ## Authors of this notebook
#
# ### Antonio Lopez — Deep Learning Scientist
#
# <div style="display:flex;gap:1rem;align-items:flex-start;margin:0.75rem 0 1.25rem 0;max-width:100%;overflow:hidden;contain:layout;">
#   <img src="https://picampus-school.com/wp-content/uploads/2025/02/antonio-lopez-pi-school-01-400x400.jpg" alt="Antonio Lopez" style="flex-shrink:0;width:140px;max-width:min(40%,140px);height:auto;"/>
#   <div>Antonio Lopez is a passionate developer with a Master&apos;s degree in Artificial Intelligence from the University of Bologna, specialising in Natural Language Processing. He works as a Deep Learning Scientist on the EVE project: an open-source LLM for Earth Observation and Earth Sciences, in collaboration with the European Space Agency&apos;s Φ-lab.</div>
# </div>
#
# ### Àlex Ramírez Atrio — Senior Deep Learning Scientist
#
# <div style="display:flex;gap:1rem;align-items:flex-start;margin:0.75rem 0 0 0;max-width:100%;overflow:hidden;contain:layout;">
#   <img src="https://picampus-school.com/wp-content/uploads/2023/06/alex-r-atrio-pi-school-02-400x400.jpg" alt="Àlex Ramírez Atrio" style="flex-shrink:0;width:140px;max-width:min(40%,140px);height:auto;"/>
#   <div>Àlex Ramírez Atrio is Senior Deep Learning Scientist at Pi School, working on EVE — an open-source LLM for Earth Observation and Earth Sciences — in collaboration with ESA Φ-lab. He obtained his PhD in Natural Language Processing at EPFL and HEIG-VD (Switzerland), focusing on machine translation and language generation. His work has focused on low-resource languages and domains, improving sequence-to-sequence models, and developing efficient multilingual and multitasking models.</div>
# </div>
#
#
# ### Jino Rohit — Deep Learning Scientist
#
# <div style="display:flex;gap:1rem;align-items:flex-start;margin:0.75rem 0 0 0;max-width:100%;overflow:hidden;contain:layout;">
#   <img src="https://picampus-school.com/wp-content/uploads/2026/04/jino-rohit-pi-school-01-400x400.jpg" alt="Jino Rohit" style="flex-shrink:0;width:140px;max-width:min(40%,140px);height:auto;"/>
#   <div>Jino Rohit is a Deep Learning Engineer with a Bachelor's degree in Computer Science from Kumaraguru College of Technology. Before joining Pi School, he worked as a Senior Data Scientist at Tata Communications, where he focused on scaling RAG applications end-to-end. He is passionate about ML Systems and open source development. At Pi School, Jino is contributing to applied AI research as part of the team.</div>
# </div>

# %% [markdown]
# # Session Description
#
# This hands-on session provides a tour of EVE, an open, agentic platform funded and supported by ESA Φ-lab for Earth Observation (EO) and Earth Sciences. Rather than presenting agentic AI in the abstract, in this session we will see how to turn services into tools that EVE can use to efficently complete a task
#
# Participants will:
#
# 1. Have an high level overview on how agentic AI works and which are its main components.
# 2. Convert external services API's to tool's that the model can invoke.
# 3. Explore the EVE's toolkit and learn how to contribute to it.
# 4. Explore EVE's platform and its agentic capability.

# %% [markdown]
# # Key Concepts: From LLMs to Agents
#
# Before diving in, here is a short glossary of the terms you will encounter throughout this notebook.
#
# - **Large Language Model (LLM)**: An AI model trained on massive amounts of text that can understand complex questions, reason across different sources of information, and generate coherent, structured text. Examples: [ChatGPT](https://openai.com/chatgpt) by OpenAI, [Claude](https://claude.ai) by Anthropic, [Gemini](https://gemini.google.com) by Google.
#
# - **General-purpose LLM**: An LLM trained on broad, diverse data (web pages, books, code, forums) so that it can handle a wide range of topics, from writing poetry to explaining quantum physics, without being specialised in any single domain. Examples: [GPT-4o](https://openai.com/index/hello-gpt-4o/) by OpenAI, [Claude Sonnet](https://www.anthropic.com/claude/sonnet) by Anthropic, [Llama](https://llama.meta.com/) by Meta.
#
# - **Domain-specific LLM**: An LLM that has been fine-tuned on data from a particular field so that it understands the field's terminology, conventions, and tasks better than a general-purpose model would. In this notebook we use [**EVE (Earth Virtual Expert)**](https://huggingface.co/eve-esa), an open-weight 24B-parameter model created by **ESA Φ-lab**, **Pi School**, and **Mistral AI**. EVE is fine-tuned from Mistral Small using ~33.5 billion tokens that mix general-domain replay data with synthetic Earth Observation and Earth Sciences content. The result is a model that significantly outperforms its base model and other models of similar size on EO-specific benchmarks, including multiple-choice QA, hallucination resistance, and open-ended domain questions, while maintaining (and even slightly improving) general-purpose capabilities such as math, coding, and instruction following. Importantly, EVE also scores high on tool-calling benchmarks, making it especially well-suited for the agentic workflows we build in this notebook. EVE is completely open-source and released under the Apache 2.0 license. Other examples of domain-specific LLMs: [BioMistral](https://huggingface.co/BioMistral/BioMistral-7B) for biomedical text, [StarCoder 2](https://huggingface.co/bigcode/starcoder2-15b) for code generation.
#
# - **Reasoning**: The ability of an LLM to break a complex question into smaller steps, evaluate intermediate results, and decide what to do next. Rather than producing a single answer from memory, a reasoning model thinks step-by-step, for example: *"I need the fire perimeter first, then I can download the right satellite image, and finally compute the burn severity index."* Examples: the [OpenAI o-series](https://openai.com/index/learning-to-reason-with-llms/) models and [Claude with extended thinking](https://docs.anthropic.com/en/docs/build-with-claude/extended-thinking) are explicitly trained to reason before answering.
#
# - **Tools**: Python functions performing one specific job: converting a place name into coordinates, downloading a satellite image, or querying a fire database. Each tool carries a machine-readable description (name, purpose, expected inputs and outputs) so the LLM can decide which tool to call and with what arguments.
#
# - **Agent**: What you get when you connect an LLM to a set of tools and let it use them in a loop. The agent works through a cycle: *reason* about what information is missing → *call* a tool to get it → *observe* the result → *decide* what to do next. This reason-act-observe loop is called **ReAct** (Reasoning + Acting), and it is the core pattern behind most LLM agents today. Examples: [LangGraph](https://langchain-ai.github.io/langgraph/) (used in this notebook), [OpenAI Agents SDK](https://openai.github.io/openai-agents-python/), [Amazon Bedrock Agents](https://aws.amazon.com/bedrock/agents/).
#
# A standalone LLM has no connection to the outside world: it cannot search information, download a satellite image, or look up yesterday's weather. Its knowledge has a cutoff date, so it knows nothing about recent events. An **agent** solves this by letting the LLM call tools at runtime and reason over their results.
#
# The difference from a traditional EO workflow is fundamental. In a scripted pipeline, you hard-code every step: download imagery, run a fixed processing chain, export results. When the question changes, the code changes. With an agent, the *capabilities* are fixed (geocoding, fire detection, spectral analysis, web search) but the *workflow* is determined at runtime based on what the user asks. The same set of tools can answer "show me fires in Greece in August 2023", "show me a S2 image of Attica in 2018", or "what caused the fire near Narbonne?", each triggering a different tool chain with no hard-coded orchestration.

# %% [markdown]
# ## Setup
#
# Run the **next cell** once to install the Python packages this notebook uses, then load environment variables from `.env`.

# %%
# Third-party packages used in this notebook (install into the **current** Jupyter kernel).
# python-dotenv — load `.env` (BASE_URL, EMAIL, PASSWORD)
# httpx           — async HTTP client (Nominatim / geocoding examples)
# geopy           — Nominatim geocoder
# requests        — EVE platform login and HTTP API calls
# fastmcp         — FastMCP server + client (MCP over HTTP; pulls in the `mcp` dependency)
# %pip install python-dotenv httpx geopy requests fastmcp
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/pty.py:95: DeprecationWarning: This process (pid=38941) is multi-threaded, use of forkpty() may lead to deadlocks in the child.
#   pid, fd = os.forkpty()
# Requirement already satisfied: python-dotenv in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (1.1.0)
# Requirement already satisfied: httpx in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.28.1)
# Requirement already satisfied: geopy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.4.1)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.33.1)
# Requirement already satisfied: fastmcp in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (3.1.1)
# Requirement already satisfied: anyio in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx) (4.9.0)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx) (1.0.7)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpcore==1.*->httpx) (0.14.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from geopy) (2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests) (2.2.3)
# Requirement already satisfied: authlib>=1.6.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastmcp) (1.6.9)
# Requirement already satisfied: cyclopts>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastmcp) (4.10.0)
# Requirement already satisfied: exceptiongroup>=1.2.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastmcp) (1.2.2)
# Requirement already satisfied: jsonref>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastmcp) (1.1.0)
# Requirement already satisfied: jsonschema-path>=0.3.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastmcp) (0.4.5)
# Requirement already satisfied: mcp<2.0,>=1.24.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastmcp) (1.26.0)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastmcp) (0.5.1)
# Requirement already satisfied: opentelemetry-api>=1.20.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastmcp) (1.41.1)
# Requirement already satisfied: packaging>=24.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastmcp) (24.2)
# Requirement already satisfied: platformdirs>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastmcp) (4.9.4)
# Requirement already satisfied: py-key-value-aio<0.5.0,>=0.4.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp) (0.4.4)
# Requirement already satisfied: pydantic>=2.11.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic[email]>=2.11.7->fastmcp) (2.11.7)
# Requirement already satisfied: pyperclip>=1.9.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastmcp) (1.9.0)
# Requirement already satisfied: pyyaml<7.0,>=6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastmcp) (6.0.2)
# Requirement already satisfied: rich>=13.9.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastmcp) (13.9.4)
# Requirement already satisfied: uncalled-for>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastmcp) (0.2.0)
# Requirement already satisfied: uvicorn>=0.35 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastmcp) (0.35.0)
# Requirement already satisfied: watchfiles>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastmcp) (1.0.5)
# Requirement already satisfied: websockets>=15.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from fastmcp) (15.0.1)
# Requirement already satisfied: httpx-sse>=0.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp) (0.4.0)
# Requirement already satisfied: jsonschema>=4.20.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp) (4.23.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp) (2.14.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0,>=1.24.0->fastmcp) (2.12.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp) (2.3.6)
# Requirement already satisfied: starlette>=0.27 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp) (0.40.0)
# Requirement already satisfied: typing-extensions>=4.9.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from mcp<2.0,>=1.24.0->fastmcp) (0.4.1)
# Requirement already satisfied: beartype>=0.20.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from py-key-value-aio<0.5.0,>=0.4.4->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp) (0.22.9)
# Requirement already satisfied: aiofile>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp) (3.9.0)
# Requirement already satisfied: keyring>=25.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp) (25.7.0)
# Requirement already satisfied: cachetools>=5.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp) (5.5.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic>=2.11.7->pydantic[email]>=2.11.7->fastmcp) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic>=2.11.7->pydantic[email]>=2.11.7->fastmcp) (2.33.2)
# Requirement already satisfied: caio<0.10.0,>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiofile>=3.5.0->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp) (0.9.25)
# Requirement already satisfied: sniffio>=1.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from anyio->httpx) (1.3.1)
# Requirement already satisfied: cryptography in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from authlib>=1.6.5->fastmcp) (43.0.3)
# Requirement already satisfied: attrs>=23.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cyclopts>=4.0.0->fastmcp) (25.3.0)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cyclopts>=4.0.0->fastmcp) (0.16)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cyclopts>=4.0.0->fastmcp) (1.3.1)
# Requirement already satisfied: docutils in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=4.0.0->fastmcp) (0.21.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2.0,>=1.24.0->fastmcp) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2.0,>=1.24.0->fastmcp) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema>=4.20.0->mcp<2.0,>=1.24.0->fastmcp) (0.24.0)
# Requirement already satisfied: pathable<0.6.0,>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jsonschema-path>=0.3.4->fastmcp) (0.5.0)
# Requirement already satisfied: jaraco.classes in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from keyring>=25.6.0->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp) (3.4.0)
# Requirement already satisfied: jaraco.functools in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from keyring>=25.6.0->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp) (4.4.0)
# Requirement already satisfied: jaraco.context in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from keyring>=25.6.0->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp) (6.1.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from opentelemetry-api>=1.20.0->fastmcp) (8.6.1)
# Requirement already satisfied: zipp>=3.20 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.20.0->fastmcp) (3.21.0)
# Requirement already satisfied: email-validator>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pydantic[email]>=2.11.7->fastmcp) (2.2.0)
# Requirement already satisfied: dnspython>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp) (2.7.0)
# Requirement already satisfied: cffi>=1.12 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cryptography->authlib>=1.6.5->fastmcp) (1.17.1)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from cffi>=1.12->cryptography->authlib>=1.6.5->fastmcp) (2.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rich>=13.9.4->fastmcp) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from rich>=13.9.4->fastmcp) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp) (0.1.2)
# Requirement already satisfied: click>=7.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from uvicorn>=0.35->fastmcp) (8.3.1)
# Requirement already satisfied: more-itertools in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from jaraco.classes->keyring>=25.6.0->py-key-value-aio[filetree,keyring,memory]<0.5.0,>=0.4.4->fastmcp) (10.7.0)
#
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import dotenv
import os

dotenv.load_dotenv()

BASE_URL = os.getenv("BASE_URL")
EMAIL = os.getenv("EMAIL")
PASSWORD = os.getenv("PASSWORD")

# %% [markdown]
# # Part I - From services to tools
#
# In this section, we explore how to take existing geospatial services and make them accessible to a large language model by wrapping them as **tools**. Tools are Python functions that an agent can invoke autonomously whenever it determines they are useful for accomplishing a specific task.
#
# In the Earth Observation domain, a rich ecosystem of service providers exposes geospatial data through a variety of protocols and APIs. Here are some key examples:
#
# - **[Copernicus Data Space Ecosystem (CDSE)](https://dataspace.copernicus.eu/):** A catalogue of satellite imagery and environmental data that can be queried using four different REST-based protocols, including [OGC STAC](https://stacspec.org/) and [OpenSearch](https://documentation.dataspace.copernicus.eu/APIs/OpenSearch.html).
# - **[European Forest Fire Information System (EFFIS)](https://effis.jrc.ec.europa.eu/):** Provides maps and verified information about fire events across Europe, accessible via the [WMS protocol](https://www.ogc.org/standard/wms/).
# - **[Google Earth Engine (GEE)](https://earthengine.google.com/):** Offers access to a vast planetary-scale geospatial catalogue through both a [REST API](https://developers.google.com/earth-engine/reference/rest) and a [Python client library](https://developers.google.com/earth-engine/guides/python_install).
# - **[NASA Earthdata](https://www.earthdata.nasa.gov/):** A portal providing access to NASA's Earth science datasets, queryable via [CMR (Common Metadata Repository)](https://www.earthdata.nasa.gov/learn/find-data/cmr) APIs covering atmosphere, land, ocean, and cryosphere data.
# - **[Sentinel Hub](https://www.sentinel-hub.com/):** A cloud-based service for processing and analysing Sentinel satellite data, accessible via a [Python library](https://sentinelhub-py.readthedocs.io/) and a [Process API](https://docs.sentinel-hub.com/api/latest/api/process/).
#
# ## What makes a good tool?
#
# The goal of creating a tool is to write a **connector function** that retrieves information from one of these services and delivers it to the agent in a usable form. The tricky part is designing tools that the agent can use *effectively*.
#
# A well-designed tool should:
#
# - **Do one thing:** A tool that fetches fire hotspots is easier to reason about, and less error-prone, than one that fetches fire hotspots *and* generates a report *and* sends an alert.
# - **Have a clear, descriptive name and docstring:** The agent decides which tool to call based on their descriptions, so clarity is critical.
# - **Accept simple, explicit inputs:** Avoid complex nested structures or ambiguous parameters, prefer plain types like strings, floats, and dates.
# - **Return structured, interpretable output.** The agent needs to be able to reason over the result, so favour clean JSON or plain text over raw binary payloads.
#
# These principles follow the composability phylosophy: small, focused tools are far more powerful when combined than a single monolithic function that tries to do everything.
#
# ## Converting a service into tools
#
# In the following sections, we will walk through a concrete example: wrapping a simple yet useful Earth Observation service into a set of tools that an agent can query. This will illustrate the full pipeline, from raw API to a tool the agent can reason about and invoke autonomously.

# %% [markdown]
# ## Nominatim
#
# [Nominatim](https://nominatim.openstreetmap.org/) is a free geocoding service built on [OpenStreetMap](https://www.openstreetmap.org/) data. It converts human-readable place names, such as "Greece", "Evia Island", or "Tenerife" into geographic coordinates and bounding boxes, with no registration or API key required.
#
# This tool serves as the **entry point for many spatial queries**. When a user asks about active fires or NDVI indices for a specific location, the model does not inherently know the precise bounding box of that place. Nominatim bridges that gap, turning a natural language place name into the structured coordinates that downstream services like EFFIS and CDSE expect.
#
# We implement two complementary operations:
# - **Forward geocoding**: place name → bounding box
# - **Reverse geocoding**: lat, long → place name

# %%
import json
import logging
import sys
from typing import Any

import httpx
from geopy.geocoders import Nominatim
from mcp.server.fastmcp import FastMCP

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(name)s — %(message)s",
    stream=sys.stderr,
)
logger = logging.getLogger("geocode-mcp")

NOMINATIM_SEARCH_URL = "https://nominatim.openstreetmap.org/search"
NOMINATIM_USER_AGENT = "GeocodeMCPServer"
TIMEOUT = 60

async def _http_get(
    url: str,
    params: dict[str, Any] | None = None,
    headers: dict[str, str] | None = None,
) -> httpx.Response:
    """Perform an async HTTP GET with sensible defaults."""
    async with httpx.AsyncClient(timeout=100, follow_redirects=True) as client:
        resp = await client.get(url, params=params, headers=headers)
        resp.raise_for_status()
        return resp
geolocator = Nominatim(user_agent=NOMINATIM_USER_AGENT, timeout=TIMEOUT)

# %% [markdown]
# ### Tool 1 - Geocode place
# This tool allow to convert a place into a geographical bounding box. The tool takes in input:
# - **place_name**: the string to be converted into bbox
# - **buffer_km**: how many kilometers we want to expand the original bbox
# - **limit**: how many candidates results to fetch, a single place can have different name's resolutions (e.g. Rhode's island)
#
# ### How it works
#
# The `geocode_place_raw` function below handles forward geocoding:
#
# 1. **Query**: Sends the place name to the [Nominatim Search API](https://nominatim.org/release-docs/develop/api/Search/), retrieving up to `limit` candidate results in JSON format.
# 2. **Parse & reorder**: Nominatim returns bounding boxes as `[south, north, west, east]`. These are reordered to `west, south, east, north` to match the convention expected by EFFIS and CDSE.
# 3. **Buffer (optional)**: If `buffer_km` is provided, the bounding box is expanded by that distance in all directions. The conversion uses the standard approximation of [~111 km per degree of latitude](https://en.wikipedia.org/wiki/Latitude#Length_of_a_degree_of_latitude).
#
# The function returns a JSON string containing the top result, all candidate results, and their associated metadata (display name, OSM type, class, centroid coordinates).
#
# > **Note on the `~111 km/degree` approximation:** this holds well for latitude, but longitude degrees shrink towards the poles (by a factor of `cos(latitude)`). For high-latitude regions, consider applying `buffer_km / (111.0 * cos(radians(lat)))` for the east–west expansion instead.

# %%
async def geocode_place_raw(
    place_name: str,
    buffer_km: float = 0.0,
    limit: int = 5,
) -> str:
    """
    Convert a place name to a bounding box.

    Geocodes a place name (city, region, country, landmark, etc.) into a
    bounding box string in "west,south,east,north" format — the same format
    accepted by get_effis_burnt_areas and other tools.

    Uses the OpenStreetMap Nominatim API (free, no API key required).

    Args:
        place_name: Name of the place to geocode (e.g. "Greece",
                    "Athens", "Evia island", "Peloponnese").
        buffer_km:  Optional buffer in km to expand the bbox (default 0).
        limit:      Maximum number of candidate results to return (default 5).

    Returns:
        JSON with the top result's bbox string (ready to pass to other tools)
        and all candidate matches.
    """
    logger.info("Geocoding place: %s", place_name)

    try:
        resp = await _http_get(
            NOMINATIM_SEARCH_URL,
            params={
                "q": place_name,
                "format": "json",
                "limit": str(limit),
                "addressdetails": "1",
            },
            headers={"User-Agent": NOMINATIM_USER_AGENT},
        )
        results = resp.json()
    except Exception as exc:
        return json.dumps({"error": f"Geocoding failed: {exc}"})

    if not results:
        return json.dumps(
            {
                "error": f"No results found for '{place_name}'.",
                "place_name": place_name,
            }
        )

    buf = buffer_km / 111.0

    def _parse_result(r: dict) -> dict:
        # Nominatim boundingbox is [south, north, west, east]
        bb = r.get("boundingbox", [])
        south, north, west, east = (
            float(bb[0]) - buf,
            float(bb[1]) + buf,
            float(bb[2]) - buf,
            float(bb[3]) + buf,
        )
        return {
            "display_name": r.get("display_name", ""),
            "bbox": f"{west:.4f},{south:.4f},{east:.4f},{north:.4f}",
            "bbox_array": [
                round(west, 4),
                round(south, 4),
                round(east, 4),
                round(north, 4),
            ],
            "lat": float(r.get("lat", 0)),
            "lon": float(r.get("lon", 0)),
            "osm_type": r.get("osm_type", ""),
            "class": r.get("class", ""),
            "type": r.get("type", ""),
        }

    parsed = [_parse_result(r) for r in results]

    return json.dumps(
        {
            "place_name": place_name,
            "top_result": parsed[0],
            "all_results": parsed,
            "total_results": len(parsed),
        }
    )

# %% [markdown]
# ### Tool 2 - Reverse geocode
# This tool performs the inverse operation of Tool 1: it converts a pair of geographic coordinates into a human-readable place name. The tool takes in input:
# - **latitude**: the latitude of the point to look up, in decimal degrees (WGS84, range `-90` to `90`)
# - **longitude**: the longitude of the point to look up, in decimal degrees (WGS84, range `-180` to `180`)
#
# ### How it works
#
# The `reverse_geocode_place_raw` function below handles reverse geocoding:
#
# 1. **Query**: Sends the `(latitude, longitude)` pair to the [Nominatim Reverse API](https://nominatim.org/release-docs/develop/api/Reverse/) through geopy's [`Nominatim.reverse`](https://geopy.readthedocs.io/en/stable/#geopy.geocoders.Nominatim.reverse) wrapper, which returns the *closest* matching feature on OpenStreetMap.
# 2. **Extract address**: Reads the formatted human-readable address from the resulting `geopy.location.Location` object via `location.address` (a single comma-separated string from country down to street/house level when available).
# 3. **Error handling**: Any network or service exception is caught and returned as a JSON `{"error": ...}` payload, so the agent can still reason over the failure instead of crashing the workflow.
#
# The function returns a JSON string containing the original `latitude`, `longitude`, and the resolved `address`.
#
# > **Note on coverage and granularity:** Nominatim only resolves coordinates that fall inside [OpenStreetMap](https://www.openstreetmap.org/) data. Points in the open ocean or in unmapped regions cause `Nominatim.reverse` to return `None`, in which case `location.address` would raise `AttributeError`, consider guarding the access with `if location is None` before serialising. The level of detail (country, city, street, building) is controlled by Nominatim's `zoom` parameter, which defaults to `18` (building level); pass a smaller `zoom` if a coarser address is preferable for the agent's reasoning.

# %%
async def reverse_geocode_place_raw(
    latitude: float,
    longitude: float,
) -> str:
    """
    Convert latitude and longitude to a place name (reverse geocoding).

    Uses the OpenStreetMap Nominatim API via geopy.

    Args:
        latitude:  Latitude coordinate.
        longitude: Longitude coordinate.

    Returns:
        JSON with the place name and address details.
    """
    logger.info("Reverse geocoding: %s, %s", latitude, longitude)

    try:
        location = geolocator.reverse(f"{latitude}, {longitude}")
    except Exception as exc:
        return json.dumps({"error": f"Reverse geocoding failed: {exc}"})

    return json.dumps(
        {
            "latitude": latitude,
            "longitude": longitude,
            "address": location.address,
        }
    )

# %% [markdown]
# ## Model-context-protocol (MCP)
#
# Now that we have defined our tools we need a way to connect them to the model and this is where MCP comes in play!

# %% [markdown]
# ### What is MCP?
# **MCP (Model Context Protocol)** is an open protocol that standardizes how AI applications connect to external data sources and tools. Think of it as **"USB-C for AI"**: a universal interface that allows AI models to interact with the world beyond their training data.
#
# Traditional AI applications require custom integrations for every external service they need to access. MCP eliminates this complexity by providing a standardized protocol that enables AI models to dynamically discover and use:
#
# - **Prompts**: pre-defined templates or instructions that guide language model interactions
# - **Resources**: structured data or content that provides additional context to the model
# - **Tools**: executable functions that allow models to perform actions or retrieve information
#
# Unlike a typical LLM pipeline with statically defined components, MCP enables dynamic discovery of the capabilities offered by the connected server. For example, you can extend functionality by simply adding a new tool to the existing server; no changes to the client are required. This makes the system modular, allowing model capabilities to be extended or updated independently.
#
#
# <img src='https://huggingface.co/datasets/mcp-course/images/resolve/main/unit1/8.png' alt='MCP main components' style='max-width:800px' />
#
# *Fig. 1. MCP main components. Source: [HuggingFace](https://huggingface.co/learn/mcp-course/unit1/key-concepts).*
#
# ### MCP Architecture
#
# MCP organizes applications into three components:
#
# 1. **Servers**: Python functions exposed as MCP-compliant tools, resources, and prompts that AI models can invoke
# 2. **Clients**: Establish connections to MCP servers, handling protocol negotiation and lifecycle management automatically
# 3. **Apps**: Provide interactive user interfaces that render directly within conversations
#
# ### Wrapping Our Functions
#
# Now we transform the raw functions we built above into **MCP tools**. Adding the `@mcp.tool()` decorator makes [FastMCP](https://gofastmcp.com) automatically:
#
# 1. **Generate JSON schemas** from function signatures and type hints
# 2. **Create tool documentation** from docstrings
# 3. **Validate inputs** before calling the function
# 4. **Handle errors** and return structured responses
# 5. **Expose the tool** through the MCP protocol
#
# Each wrapper is a thin shell that delegates to the corresponding `*_raw` function, keeping tool logic separate from protocol plumbing

# %% [markdown]
# ### FastMCP
#
# [FastMCP](https://gofastmcp.com) is a Python framework that automates the complexity of building MCP servers.

# %%
from fastmcp import FastMCP

mcp = FastMCP("Geocode")


@mcp.tool()
async def geocode_place(place_name: str, buffer_km: float = 0.0, limit: int = 5) -> str:
    """Convert a place name to a bounding box.

    Args:
        place_name: Name of the place (e.g. "Greece", "Athens", "Evia island").
        buffer_km: Optional buffer in km to expand the bbox.
        limit: Maximum number of candidate results.
    """
    return await geocode_place_raw(place_name, buffer_km, limit)


@mcp.tool()
async def reverse_geocode_place(
    latitude: float,
    longitude: float,
) -> str:
    """Convert latitude and longitude to a place name (reverse geocoding).

    Args:
        latitude: Latitude coordinate.
        longitude: Longitude coordinate.

    Returns:
        JSON with the place name and address details.
    """
    return await reverse_geocode_place_raw(latitude, longitude)

# %% [markdown]
# ### Run the MCP Server
#
# MCP servers support two transport mechanisms:
#
# 1. **STDIO**: for local communication where the host launches the server as a subprocess (used by Claude Desktop, Cursor, etc.)
# 2. **HTTPS**: for network access where a single server serves multiple clients
#
# In this notebook, we run the server over HTTPS in a daemon thread so it stays alive alongside notebook cells.

# %%
import threading
import asyncio
import socket
import time

MCP_HOST = "0.0.0.0"
MCP_PORT = 8005


def _port_is_in_use(port: int, host: str = "127.0.0.1") -> bool:
    """Return True if something is already listening on (host, port)."""
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        s.settimeout(0.5)
        try:
            s.connect((host, port))
            return True
        except (ConnectionRefusedError, socket.timeout, OSError):
            return False


def run_mcp_server_in_thread():
    logging.getLogger("uvicorn.access").setLevel(logging.WARNING)
    asyncio.run(mcp.run(transport="http", host=MCP_HOST, port=MCP_PORT, log_level="warning"))


existing_thread = globals().get("server_thread")
if existing_thread is not None and existing_thread.is_alive():
    print("MCP server already running in this kernel (reusing existing thread)")
elif _port_is_in_use(MCP_PORT):
    raise RuntimeError(
        f"Port {MCP_PORT} is already in use by another process. "
        f"Either stop it (macOS/Linux: `lsof -i :{MCP_PORT}` then `kill <pid>`) "
        f"or change MCP_PORT above."
    )
else:
    server_thread = threading.Thread(target=run_mcp_server_in_thread, daemon=True)
    server_thread.start()
    time.sleep(2)

print(f"MCP server running at http://localhost:{MCP_PORT}/mcp")
print(f"Thread alive: {server_thread.is_alive()}")
# Out:
# MCP server already running in this kernel (reusing existing thread)
# MCP server running at http://localhost:8005/mcp
# Thread alive: True

# %% [markdown]
# ### Create MCP Client and Discover Tools
#
# Now let's connect a client to our running server and discover what tools it offers.
#
# The `client.list_tools()` method returns structured information about each tool, name, description, and input schema. This is the same discovery mechanism an AI agent uses to understand how to interact with the tools.

# %%
import time
time.sleep(5)

from fastmcp import Client

client = Client("http://localhost:8005/mcp")

# %%
async with client:
    result = await client.list_tools()
# Out:
# 2026-05-14 11:39:26,315 [INFO] httpx — HTTP Request: POST http://localhost:8005/mcp "HTTP/1.1 200 OK"
# 2026-05-14 11:39:26,316 [INFO] mcp.client.streamable_http — Received session ID: c2f43a6e6d65446e8050a4b5907625d6
# 2026-05-14 11:39:26,319 [INFO] mcp.client.streamable_http — Negotiated protocol version: 2025-11-25
# 2026-05-14 11:39:26,330 [INFO] httpx — HTTP Request: POST http://localhost:8005/mcp "HTTP/1.1 202 Accepted"
# 2026-05-14 11:39:26,335 [INFO] httpx — HTTP Request: GET http://localhost:8005/mcp "HTTP/1.1 200 OK"
# 2026-05-14 11:39:26,338 [INFO] httpx — HTTP Request: POST http://localhost:8005/mcp "HTTP/1.1 200 OK"
# 2026-05-14 11:39:26,349 [INFO] httpx — HTTP Request: DELETE http://localhost:8005/mcp "HTTP/1.1 200 OK"

# %%
def pretty_print_tools(tools):
    """Pretty print MCP tools in a readable format."""
    print("=" * 80)
    print(f"{'MCP TOOLS AVAILABLE':^80}")
    print("=" * 80)
    print(f"\nTotal Tools: {len(tools)}\n")
    for idx, tool in enumerate(tools, 1):
        print(f"\n{'─' * 80}")
        print(f"[{idx}] {tool.name}")
        print(f"{'─' * 80}")
        if tool.description:
            print(f"\nDescription:")
            for line in tool.description.strip().split('\n'):
                print(f"   {line}")
        if tool.inputSchema:
            print(f"\nInput Parameters:")
            props = tool.inputSchema.get('properties', {})
            required = tool.inputSchema.get('required', [])
            for param_name, param_info in props.items():
                param_type = param_info.get('type', 'unknown')
                default = param_info.get('default')
                req_marker = "REQUIRED" if param_name in required else "optional"
                default_str = f" (default: {repr(default)})" if default is not None else ""
                print(f"      {param_name}: {param_type} [{req_marker}]{default_str}")
    print(f"\n{'=' * 80}\n")

pretty_print_tools(result)
# Out:
# ================================================================================
#                               MCP TOOLS AVAILABLE
# ================================================================================
#
# Total Tools: 2
#
#
# ────────────────────────────────────────────────────────────────────────────────
# [1] geocode_place
# ────────────────────────────────────────────────────────────────────────────────
#
# Description:
#    Convert a place name to a bounding box.
#
#    Args:
#        place_name: Name of the place (e.g. "Greece", "Athens", "Evia island").
#        buffer_km: Optional buffer in km to expand the bbox.
#        limit: Maximum number of candidate results.
#
# Input Parameters:
#       place_name: string [REQUIRED]
#       buffer_km: number [optional] (default: 0.0)
#       limit: integer [optional] (default: 5)
#
# ────────────────────────────────────────────────────────────────────────────────
# [2] reverse_geocode_place
# ────────────────────────────────────────────────────────────────────────────────
#
# Description:
#    Convert latitude and longitude to a place name (reverse geocoding).
#
#    Args:
#        latitude: Latitude coordinate.
#        longitude: Longitude coordinate.
#
#    Returns:
#        JSON with the place name and address details.
#
# Input Parameters:
#       latitude: number [REQUIRED]
#       longitude: number [REQUIRED]
#
# ================================================================================

# %% [markdown]
# ## Invoke MCP Tools
#
# Let's use the client to invoke our geocoding tool. This demonstrates the exact same interaction pattern an AI agent would follow.

# %% [markdown]
# ### Example: Geocode a Place Name
#
# Convert "Greece" into a bounding box. The returned bbox string is ready to pass directly to `get_effis_burnt_areas` or `compute_metrics`.

# %%
async with client:
    geocode_result = await client.call_tool("geocode_place", {"place_name": "Greece"})

geocode_data = json.loads(geocode_result.data)
print(f"Place: {geocode_data['place_name']}")
print(f"Bbox:  {geocode_data['top_result']['bbox']}")
print(f"Name:  {geocode_data['top_result']['display_name']}")
# Out:
# 2026-05-14 11:39:26,391 [INFO] httpx — HTTP Request: POST http://localhost:8005/mcp "HTTP/1.1 200 OK"
# 2026-05-14 11:39:26,392 [INFO] mcp.client.streamable_http — Received session ID: c15b35b49a66471087577efb85806699
# 2026-05-14 11:39:26,393 [INFO] mcp.client.streamable_http — Negotiated protocol version: 2025-11-25
# 2026-05-14 11:39:26,403 [INFO] httpx — HTTP Request: GET http://localhost:8005/mcp "HTTP/1.1 200 OK"
# 2026-05-14 11:39:26,404 [INFO] httpx — HTTP Request: POST http://localhost:8005/mcp "HTTP/1.1 202 Accepted"
# 2026-05-14 11:39:26,408 [INFO] httpx — HTTP Request: POST http://localhost:8005/mcp "HTTP/1.1 200 OK"
# 2026-05-14 11:39:26,790 [INFO] httpx — HTTP Request: POST http://localhost:8005/mcp "HTTP/1.1 200 OK"
# 2026-05-14 11:39:26,795 [INFO] httpx — HTTP Request: DELETE http://localhost:8005/mcp "HTTP/1.1 200 OK"
# Place: Greece
# Bbox:  19.1128,34.7189,29.6838,41.7489
# Name:  Ελλάς

# %% [markdown]
# ### Example: Reverse Geocode
#
# Let's convert a point into a place name.

# %%
async with client:
    reverse_geocode_result = await client.call_tool("reverse_geocode_place", {"latitude": 39.0742, "longitude": 21.8243})

reverse_geocode_data = json.loads(reverse_geocode_result.data)
print(f"Address: {reverse_geocode_data['address']}")
# Out:
# 2026-05-14 11:39:26,818 [INFO] httpx — HTTP Request: POST http://localhost:8005/mcp "HTTP/1.1 200 OK"
# 2026-05-14 11:39:26,818 [INFO] mcp.client.streamable_http — Received session ID: 6eb4fe667a26434cabfa3a21cf339b79
# 2026-05-14 11:39:26,819 [INFO] mcp.client.streamable_http — Negotiated protocol version: 2025-11-25
# 2026-05-14 11:39:26,822 [INFO] httpx — HTTP Request: POST http://localhost:8005/mcp "HTTP/1.1 202 Accepted"
# 2026-05-14 11:39:26,823 [INFO] httpx — HTTP Request: GET http://localhost:8005/mcp "HTTP/1.1 200 OK"
# 2026-05-14 11:39:26,827 [INFO] httpx — HTTP Request: POST http://localhost:8005/mcp "HTTP/1.1 200 OK"
# 2026-05-14 11:39:27,040 [INFO] httpx — HTTP Request: POST http://localhost:8005/mcp "HTTP/1.1 200 OK"
# 2026-05-14 11:39:27,047 [INFO] httpx — HTTP Request: DELETE http://localhost:8005/mcp "HTTP/1.1 200 OK"
# Address: Φουρνά - Βράχα, Κ. Κλειστού, Βράχα, Δημοτική Ενότητα Φουρνά, Δήμος Καρπενησίου, Περιφερειακή Ενότητα Ευρυτανίας, Περιφέρεια Στερεάς Ελλάδας, Αποκεντρωμένη Διοίκηση Θεσσαλίας - Στερεάς Ελλάδος, 360 80, Ελλάς

# %% [markdown]
# # Part II - EVE's Tool Registry
#
# EVE's **Tool Registry** is a centralized repository of MCP servers, built and maintained by the EVE team and the broader community. The registry is designed to be open and collaborative: companies, academic institutions, students, and domain experts are all welcome to contribute by wrapping their favourite services into MCP servers. The goal is to foster community cooperation and make tool sharing as seamless as possible, so that anyone can check whether their favourite service is already supported and, if not, contribute their own integration.
#
# The tools currently available in the registry have been developed by the EVE team and ESA.
#
# Every server accepted into the registry is automatically deployed and made available through the EVE system. It is important to note that the EVE project is responsible for deploying the MCP servers themselves, not the underlying services they depend on. If a server relies on a specific ML model or a data repository, that infrastructure must be deployed and maintained by the respective service provider.
#
# The registry is designed around a few core principles:
#
# - **Quality-gated**: every contribution goes through a review process before being accepted
# - **Platform-integrated**: published tools are exposed directly through EVE
# - **MCP-compliant**: all servers follow the MCP standard
# - **Self-contained**: each server is completely independent; just copy its folder into your project, no external dependencies required
#
# Let's now explore the repository structure:
#
# ```
# repo/
# ├── .github/
# │   └── workflows/
# │       ├── deploy.yml          # Deploys servers to AgentCore on push to main
# │       └── pr-checks.yml       # Validates PRs before merge
# ├── scripts/
# │   ├── deploy_server.py        # Build + deploy logic (used by CI)
# │   ├── detect_changed.py       # Detects which servers changed in a push
# │   └── validate_pr.py          # PR validation checks
# ├── shared/
# │   └── Dockerfile              # Shared Dockerfile for all servers
# ├── servers/
# │   ├── effis/                  # Example: Fire Detection server
# │   ├── eve_retrieval/          # Example: EVE Retrieval server
# │   └── your-server/            # <-- Your new server goes here
# ├── ruff.toml                   # Linter configuration
# └── CODEOWNERS                  # Protects shared infrastructure paths
# ```

# %% [markdown]
# ## Available servers
#
#
# The `tools/` repository contains several MCP servers:
#
# | Server | Purpose | Key Tools |
# |-------|--------|----------|
# | `effis` | Wildfire detection & burn severity | `geocode_place`, `get_effis_burnt_areas`, `compute_metrics` |
# | `eve_retrieval` | Document & knowledge retrieval | `retrieve` |
# | `serpapi` | Web search | `search_google` |
# | `eotdl` | Search for datasets, models, and pipelines in the EOTDL | `eotdl_search` |
# | `eodashboard` | Searches narratives, themes and indicators from the joint ESA / NASA / JAXA EO Dashboard | `list_narratives` |
# | `trallie` | Structured data extraction | `extract_data` |
#
# Each server lives in its own directory under `tools/servers/` and is independently deployed to AWS Bedrock AgentCore.

# %% [markdown]
# ## Login
#
# We first need to login and get an access token to access the MCP servers deployed. Let's see how we can do it.

# %%
import requests


def login(base_url: str, email: str, password: str) -> str:
    print(f"Logging in with email: {email} and password: ***")
    resp = requests.post(
        f"{base_url}/login",
        json={"email": email, "password": password},
        timeout=30,
    )
    if resp.status_code != 200:
        print(f"Login failed ({resp.status_code}): {resp.text}")
    print(resp.json())
    token = resp.json()["access_token"]
    return token

# %%
access_token = login(BASE_URL, EMAIL, PASSWORD)
# Out:
# Logging in with email: pischool@eve.com and password: ***
# {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE3Nzg3NTI0NjcsInN1YiI6IjY5ZjhhMTYxODIwMjYzMTI4YTllZjZhOSIsImF1ZCI6ImFjY2VzcyJ9.QGaCN6XzBVHtJKy5yKkPSjJPVNYn_nXdCZwn2krRk_E', 'refresh_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE3NzkzNTYzNjcsInN1YiI6IjY5ZjhhMTYxODIwMjYzMTI4YTllZjZhOSIsImp0aSI6IjgyOTM3Y2ZiLWUwZjEtNDlkNS05MzM1LWFkM2FhODhhY2QwNyIsImF1ZCI6InJlZnJlc2gifQ.B5L88pxxOiETgrE4lisdnCmcMVupSn-zd02Q9bgdqwg'}

# %% [markdown]
# ## List the available MCP servers
#
# We can now use the access token to call the different endpoints we have. Let's try to list all the MCP servers we have registered in the repository.

# %%
def get_mcp_servers(
    base_url: str,
    token: str,
    page: int = 1,
    limit: int = 10,
    timeout: int = 10,
):
    url = f"{base_url}/mcp-servers"
    
    headers = {
        "accept": "application/json",
        "Authorization": f"Bearer {token}",
    }

    params = {
        "page": page,
        "limit": limit,
    }

    response = requests.get(url, headers=headers, params=params, timeout=timeout)
    response.raise_for_status()

    resp = response.json()["data"]

    return [
        {
            "server_id": row["id"],
            "server_name": row["name"],
            "description": row["description"],
            "url": row["config"].get("url"),
            "transport": row["config"].get("transport"),
        }
        for row in resp
    ]

# %%
mcp_servers = get_mcp_servers(BASE_URL, access_token)

print("=" * 80)
print(f"{'AVAILABLE MCP SERVERS':^80}")
print("=" * 80)
print(f"\nTotal Servers: {len(mcp_servers)}\n")

for idx, server in enumerate(mcp_servers, 1):
    print(f"\n{'─' * 80}")
    print(f"[{idx}] {server['server_name']}")
    print(f"{'─' * 80}")
    print(f"   Description : {server['description']}")
    print(f"   Server ID   : {server['server_id']}")
    print(f"   Transport   : {server['transport']}")
    print(f"   URL         : {server['url']}")

print(f"\n{'=' * 80}\n")
# Out:
# ================================================================================
#                              AVAILABLE MCP SERVERS
# ================================================================================
#
# Total Servers: 9
#
#
# ────────────────────────────────────────────────────────────────────────────────
# [1] eve_mcp
# ────────────────────────────────────────────────────────────────────────────────
#    Description : AgentCore MCP runtime: eve_mcp
#    Server ID   : 6a0437476c23071aca0f4417
#    Transport   : streamable_http
#    URL         : https://staging-agentic-api.eve-chat.chat/mcp/eve_mcp
#
# ────────────────────────────────────────────────────────────────────────────────
# [2] trallie
# ────────────────────────────────────────────────────────────────────────────────
#    Description : Extracts structured data from unstructured text using LLMs
#    Server ID   : 6a0330fdc482557aad07c7b0
#    Transport   : streamable_http
#    URL         : https://staging-agentic-api.eve-chat.chat/mcp/trallie
#
# ────────────────────────────────────────────────────────────────────────────────
# [3] dummy_image
# ────────────────────────────────────────────────────────────────────────────────
#    Description : Returns a simple generated sample PNG image.
#    Server ID   : 69fc643a9b5636b999ef714a
#    Transport   : streamable_http
#    URL         : https://staging-agentic-api.eve-chat.chat/mcp/dummy_image
#
# ────────────────────────────────────────────────────────────────────────────────
# [4] effis
# ────────────────────────────────────────────────────────────────────────────────
#    Description : Wildfire analysis server (burnt areas + fire impact metrics from Copernicus/Sentinel data).
#    Server ID   : 69fc643a9b5636b999ef7149
#    Transport   : streamable_http
#    URL         : https://staging-agentic-api.eve-chat.chat/mcp/effis
#
# ────────────────────────────────────────────────────────────────────────────────
# [5] eodashboard
# ────────────────────────────────────────────────────────────────────────────────
#    Description : Searches EO Dashboard narratives/themes and maps them to STAC collections/items.
#    Server ID   : 69fc643a9b5636b999ef7148
#    Transport   : streamable_http
#    URL         : https://staging-agentic-api.eve-chat.chat/mcp/eodashboard
#
# ────────────────────────────────────────────────────────────────────────────────
# [6] eotdl
# ────────────────────────────────────────────────────────────────────────────────
#    Description : Proxy search for EO datasets/models/pipelines from EOTDL.
#    Server ID   : 69fc643a9b5636b999ef7147
#    Transport   : streamable_http
#    URL         : https://staging-agentic-api.eve-chat.chat/mcp/eotdl
#
# ────────────────────────────────────────────────────────────────────────────────
# [7] eve_retrieval
# ────────────────────────────────────────────────────────────────────────────────
#    Description : Queries EVE collections and returns retrieved documents.
#    Server ID   : 69fc643a9b5636b999ef7146
#    Transport   : streamable_http
#    URL         : https://staging-agentic-api.eve-chat.chat/mcp/eve_retrieval
#
# ────────────────────────────────────────────────────────────────────────────────
# [8] geocode
# ────────────────────────────────────────────────────────────────────────────────
#    Description : Geocoding using Nominatim (OSM) API.
#    Server ID   : 69fc643a9b5636b999ef7145
#    Transport   : streamable_http
#    URL         : https://staging-agentic-api.eve-chat.chat/mcp/geocode
#
# ────────────────────────────────────────────────────────────────────────────────
# [9] serpapi
# ────────────────────────────────────────────────────────────────────────────────
#    Description : Google search via SerpAPI (titles, links, snippets).
#    Server ID   : 69fc64399b5636b999ef7144
#    Transport   : streamable_http
#    URL         : https://staging-agentic-api.eve-chat.chat/mcp/serpapi
#
# ================================================================================

# %% [markdown]
# ## List the tools under effis server
#
# We can now select one server-id from the list and see which tools are available

# %%
def get_mcp_server_tools(
    base_url: str,
    token: str,
    server_id: str,
    timeout: int = 10,
):
    url = f"{base_url}/mcp-servers/{server_id}"
    
    headers = {
        "accept": "application/json",
        "Authorization": f"Bearer {token}",
    }

    response = requests.get(url, headers=headers, timeout=timeout)
    response.raise_for_status()

    data = response.json()
    tools = data.get("tools", [])

    print("=" * 80)
    print(f"{'MCP TOOLS AVAILABLE':^80}")
    print("=" * 80)
    print(f"\nTotal Tools: {len(tools)}\n")

    for idx, tool in enumerate(tools, 1):
        print(f"\n{'─' * 80}")
        print(f"[{idx}] {tool.get('name', 'Unnamed Tool')}")
        print(f"{'─' * 80}")

        description = tool.get("description")
        if description:
            print(f"\nDescription:")
            for line in description.strip().split('\n'):
                print(f"   {line}")

    print(f"\n{'=' * 80}\n")

# %%
tools = get_mcp_server_tools(BASE_URL, access_token, "69fc64399b5636b999ef7144")
# Out:
# ================================================================================
#                               MCP TOOLS AVAILABLE
# ================================================================================
#
# Total Tools: 1
#
#
# ────────────────────────────────────────────────────────────────────────────────
# [1] serpapi_search_google
# ────────────────────────────────────────────────────────────────────────────────
#
# Description:
#    Search Google via SerpAPI and return organic results.
#
#    Args:
#        query: The search query string.
#        num: Maximum number of results to return (default 10).
#
#    Returns:
#        JSON string containing a list of results with title, url, and snippet.
#
# ================================================================================

# %% [markdown]
# ### Run an MCP server locally
#
# If you want to run any of the server in the toolkit in your local you can:
#
# **1. Clone the repository**
# ```bash
# git clone https://github.com/eve-esa/tools.git
# ```
#
# **2. Change the directory**
#
# ```bash
# cd tools/servers/eve_retrieval
# ```
# **3. Create and activate a venv**
# ```bash
# python -m venv venv
# source venv/bin/activate
# ```
# **4. Install dependencies**
# ```bash
# pip install -r requirements.txt
# ```
# **5. Run the server.**
# ```bash
# python3 server.py
# ```
#
# **Important**
# Remember to set the `.env` when you run it since you are doing it on your local machine

# %% [markdown]
# ## How to contribute
#
# Now that we implemented an MCP server in the last section let's see how you can contribute and add it to the EVE's toolkit!
#
# **1. Clone the repository**
# ```bash
# git clone https://github.com/eve-esa/tools.git
# ```
#
# **2. Create a server directory**
#
# ```bash
# mkdir tools/servers/my-new-server
# ```
#
# **2. Write server.py**
# Use the FastMCP framework as showed and connect your favourite services:
#
# ```python
# from mcp.server.fastmcp import FastMCP
#
# mcp = FastMCP("My Tool", host="0.0.0.0", port=8000, stateless_http=True)
#
# @mcp.tool()
# async def my_tool(query: str, limit: int = 10) -> str:
#     """Short description of what this tool does.
#
#     Args:
#         query: What to search for.
#         limit: Maximum number of results to return.
#
#     Returns:
#         JSON string with the results.
#     """
#     results = {"query": query, "results": []}
#     import json
#     return json.dumps(results)
#
# if __name__ == "__main__":
#     import argparse
#     parser = argparse.ArgumentParser()
#     parser.add_argument("--transport", choices=["stdio", "streamable-http"], default="streamable-http")
#     args = parser.parse_args()
#     if args.transport == "stdio":
#         mcp.run(transport="stdio")
#     else:
#         mcp.run(transport="streamable-http")
# ```
#
# **3. Add requirements.txt**
#
# ```
# mcp[cli]>=1.2.0
# ```
#
# **4. Add .env.template (if needed)**
# Write here the environments variable you need.
#
# ```
# MY_API_KEY=${MY_API_KEY}
# ```
#
# **5. Submit a PR**
#
# Create a branch, commit your server directory, and open a PR against `main`. The automated checks will verify:
#
# - [ ] `server.py` follows the FastMCP entrypoint contract and boots up with no error.
# - [ ] `requirements.txt` exists with version constraints
# - [ ] No secrets committed
# - [ ] Docker build succeeds
#
# For more information please refer to the [`tools/CONTRIBUTING.md`](tools/CONTRIBUTING.md) for the full contribution guide. [Here](https://github.com/eve-esa/tools/pull/18) you can find an example of PR to the repository.

# %% [markdown]
# # Part III - EVE Platform Overview
#
# EVE exposes its capabilities through a full-featured REST API that covers everything from basic document retrieval to full agentic reasoning loops. This section gives you a practical tour of the platform: we start with two foundational endpoints, then introduce the experimental agentic layer that ties together the model, the RAG pipeline, and the MCP tools we built in the previous sections.

# %% [markdown]
# ## API Capabilities
#
# EVE exposes a full set of [APIs](https://staging-agentic-api.eve-chat.chat/docs) that provide programmatic access to the entire system. The available endpoints are organized into the following categories:
#
# - **Auth** — User registration, login, JWT token management, and account activation.
# - **User** — Profile management and token usage monitoring.
# - **Forgot Password** — Password reset flow via email verification codes.
# - **Conversations** — Create, list, retrieve, update, and delete conversations.
# - **Messages** — Send messages, stream responses, retry generation, submit feedback, and run hallucination detection.
# - **Collections** — Manage public and private document collections backed by a vector store.
# - **Documents** — Upload, list, retrieve, and delete documents within collections.
# - **MCP Servers** — Register and manage MCP server configurations available as agent tools.
# - **Health** — Liveness probe for service monitoring.
#
# In the following two hands-on examples we walk through `/retrieve`, which runs the retrieval pipeline without calling the LLM, and `POST /conversations/{conversation_id}/messages`, which runs the full RAG pipeline — retrieval followed by grounded LLM generation — within a conversation thread.

# %% [markdown]
# For each endpoint we cover **what it does**, **how to call it**, and **what the response looks like**. All calls use the same `BASE_URL` and `access_token` set up below.

# %%
access_token = login(BASE_URL, EMAIL, PASSWORD)
# Out:
# Logging in with email: pischool@eve.com and password: ***
# {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE3Nzg3NTI0NzAsInN1YiI6IjY5ZjhhMTYxODIwMjYzMTI4YTllZjZhOSIsImF1ZCI6ImFjY2VzcyJ9.0yj77MhQxAlOCoEZhJF2HeZmf8Mq-EYKYIWL5wHhvUc', 'refresh_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE3NzkzNTYzNzAsInN1YiI6IjY5ZjhhMTYxODIwMjYzMTI4YTllZjZhOSIsImp0aSI6IjMyMzlmMTQ5LWE4NGQtNGIxNi04OWJiLTlkMWFkM2Y0OWMyZiIsImF1ZCI6InJlZnJlc2gifQ.psShDIdwpZ7LDILigIHD0zd9kanZFdnumVQHM9XwMw8'}

# %% [markdown]
# ### 1. `POST /retrieve` — Document Retrieval
#
# Runs the retrieval pipeline **without** calling the LLM. Useful for inspecting what documents would be retrieved for a given query before sending it to the model, or for building custom answer-generation pipelines on top of the retrieved context.
#
# ---
#
# #### RAG Pipeline — High-Level View
#
# The `/retrieve` endpoint implements a classic **two-stage Retrieve-and-Rerank** pipeline. Here is what happens under the hood for every query:
#
# ```
# User Query
#     │
#     ▼
# ┌──────────────────────────────┐
# │  1. Query Rewriting          │  The raw query may be automatically
# │                              │  rephrased to be more retrieval-friendly
# │                              │  (e.g. expanding acronyms, removing filler
# └──────────────┬───────────────┘  words, or hypothetical-document style)
#                │
#                ▼
# ┌──────────────────────────────┐
# │  2. Embedding                │  The (rewritten) query is encoded as a
# │  (Qwen/Qwen3-Embedding-4B)   │  dense vector by a transformer embedding
# └──────────────┬───────────────┘  model — one float per dimension
#                │
#                ▼
# ┌──────────────────────────────┐
# │  3. Vector Search            │  Similarity search
# │     → raw `score`            │  computes cosine similarity between the
# │     score_threshold = 0.7    │  query vector and all document vectors
# └──────────────┬───────────────┘  stored in the selected collections.
#                │                  Documents below the threshold are dropped.
#                ▼
# ┌──────────────────────────────┐
# │  4. Reranking                │  A cross-encoder re-scores each surviving
# │     → `reranking_score`      │  candidate by reading the query AND the
# │                              │  document text together. This is heavier
# └──────────────┬───────────────┘  than embedding similarity but much more
#                │                  precise as a relevance signal.
#                ▼
#     Top-k Documents returned
#     (id · score · reranking_score
#      collection_name · text · payload · latencies)
# ```
#
#
# ---
#
# **Request body**
#
# | Field | Type | Default | Description |
# |---|---|---|---|
# | `query` | string | — | Search query |
# | `filters` | dict | null | Metadata filters |
# | `embeddings_model` | string | `Qwen/Qwen3-Embedding-4B` | Embedding model |
# | `k` | int | 3 | Number of documents to retrieve |
# | `score_threshold` | float | 0.5 | Minimum similarity score |
# | `public_collections` | list[str] | default list | Collections to include |
#
# **Response**: A list of documents retrieved containing `id`, `score`, `reranking_score`, `collection_name`, `text`, and `payload` along with the corresponding `latencies`.

# %%
def retrieve(base_url: str, token: str, query: str, k: int = 3) -> dict:
    """Document Retrieval"""
    payload = {"query": query, "k": k, "public_collections": ["qwen-512-filtered", "Wiley AI Gateway", "Wikipedia EO"]}
    resp = requests.post(
        f"{base_url}/retrieve",
        json=payload,
        headers={"Authorization": f"Bearer {token}"},
        timeout=30,
    )
    resp.raise_for_status()
    return resp.json()


def display_retrieved(result: dict):
    """Pretty-print retrieval results with annotated field explanations."""
    docs = result.get("retrieved_docs", [])
    latencies = result.get("latencies", {})
    sep = "─" * 72

    # Latency breakdown
    if latencies:
        print("⏱  Pipeline Latencies")
        for stage, secs in latencies.items():
            print(f"   {stage:<30} {secs:.3f} s")
        print()

    if not docs:
        print("No documents returned.")
        return

    print(f"📄  {len(docs)} document(s) retrieved\n")

    for i, doc in enumerate(docs, 1):
        score           = doc.get("score")
        reranking_score = doc.get("reranking_score")
        collection      = doc.get("collection_name", "N/A")
        text            = doc.get("text", "")
        payload         = doc.get("payload", {})

        print(sep)
        print(f"  Document {i}  |  Collection: {collection}")
        print(sep)

        if score is not None:
            bar = "█" * int(score * 20)
            print(f"  score           {score:.4f}  [{bar:<20}]")
            print(f"                  ↳ cosine similarity query↔doc embedding"
                  " (first-pass filter, ≥ 0.7 kept)")
        if reranking_score is not None:
            print(f"  reranking_score {reranking_score:.4f}")
            print(f"                  ↳ cross-encoder score; final ranking"
                  " signal — higher = more relevant")

        snippet = text[:400].replace("\n", " ") + ("…" if len(text) > 400 else "")
        print(f"  text snippet    {snippet}")

        if payload:
            print("  metadata:")
            for k, v in payload.items():
                print(f"    {k}: {v}")
        print()


retrieved = retrieve(BASE_URL, access_token, "How to calibrate Sentinel-2?", k=3)
display_retrieved(retrieved)
# Out:
# ⏱  Pipeline Latencies
#    reranking_latency              1.252 s
#    query_embedding_latency        0.676 s
#    qdrant_retrieval_latency       0.109 s
#    mcp_retrieval_latency          1.761 s
#    rewrite                        1.485 s
#
# 📄  10 document(s) retrieved
#
# ────────────────────────────────────────────────────────────────────────
#   Document 1  |  Collection: EVE open access
# ────────────────────────────────────────────────────────────────────────
#   score           0.7254  [██████████████      ]
#                   ↳ cosine similarity query↔doc embedding (first-pass filter, ≥ 0.7 kept)
#   reranking_score 0.9961
#                   ↳ cross-encoder score; final ranking signal — higher = more relevant
#   text snippet    An outline of calibration procedures for Landsat and Sentinel 2 is provided with extensive references to detailed information for the interested reader. After this introduction to the sensors, a calibration comparison of the two instruments is presented. The next section of the paper presents the current status and limitations of data operability with these sensors based on four perspectives. Last…
#   metadata:
#     journal: Remote Sensing
#     headers: ['######Abstract']
#     citation_count: 0
#     title: Observations and Recommendations for the Calibration of Landsat 8 OLI and Sentinel 2 MSI for Improved Data Interoperability
#     file_path: mdpi/2633df9a_d147_4da5_995a_b9bea788d323.md
#     year: 2018
#     content: An outline of calibration procedures for Landsat and Sentinel 2 is provided with extensive references to detailed information for the interested reader. After this introduction to the sensors, a calibration comparison of the two instruments is presented. The next section of the paper presents the current status and limitations of data operability with these sensors based on four perspectives. Lastly, the recommendations produced by the panel are presented and the paper closes with a short summary.
#     url: https://doi.org/10.3390/rs10091340
#     n_citations: 62
#     publisher: MDPI AG
#     authors: Dennis Helder, Brian Markham, Ron Morfitt, Jim Storey, Julia Barsi, Ferran Gascon, Sebastien Clerc, Bruno LaFrance, Jeff Masek, David P. Roy, Adam Lewis, Nima Pahlevan
#     pipeline_metadata: {'newline_count': 0, 'word_count': 76, 'pii_tokens_percentage': 0.0}
#     doi: 10.3390/rs10091340
#     id: 265775
#
# ────────────────────────────────────────────────────────────────────────
#   Document 2  |  Collection: EVE open access
# ────────────────────────────────────────────────────────────────────────
#   score           0.7155  [██████████████      ]
#                   ↳ cosine similarity query↔doc embedding (first-pass filter, ≥ 0.7 kept)
#   reranking_score 0.0022
#                   ↳ cross-encoder score; final ranking signal — higher = more relevant
#   text snippet    # Scientific data   Open A dataset of topographic correction coefficients for shortwave downward radiation over the Pan-Third Pole   [PERSON]   1 School of Geospatial Engineering and Science, SunYat-sen University & Southern Marine Science and Engineering Guangdong Laboratory (Zhuhai), Zhuhai, 519000, China. 'Key Laboratory of Comprehensive Observation of Polar Environment (SunYat-sen University),…
#   metadata:
#     year: 2024
#     file_path: ncbi/debaec5e-1da0-45b0-88bf-3f7a8360f484.pdf
#     n_citations: 0
#     title: A dataset of topographic correction coefficients for shortwave downward radiation over the Pan-Third Pole
#     doi: 10.1038/s41597-024-03616-2
#     publisher: Springer Science and Business Media LLC
#     url: https://doi.org/10.1038/s41597-024-03616-2
#     journal: Scientific Data
#     headers: ['#Scientific data']
#     pipeline_metadata: {'pii_tokens_percentage': 0.016736401673640166, 'word_count': 478, 'newline_count': 9}
#     content: # Scientific data
# Open A dataset of topographic correction coefficients for shortwave downward radiation over the Pan-Third Pole
# [PERSON]
# 1 School of Geospatial Engineering and Science, SunYat-sen University & Southern Marine Science and Engineering Guangdong Laboratory (Zhuhai), Zhuhai, 519000, China. 'Key Laboratory of Comprehensive Observation of Polar Environment (SunYat-sen University), Ministry of Education, Zhuhai, 519000, China. 'Key Laboratory of Natural Resources Monitoring in Tropical and Subtropical area of South China, Ministry of natural resources, Zhuhai, 519000, China. 'Guangdong Provincial Key Laboratory of Geodynamics and Geohhazards, School of Earth Sciences and Engineering, Sun Yat-sen University, Zhuhai, 519000, China. 'State Key Laboratory of Remote Sensing Science, Aerospace Information Research Institute, Chinese Academy of Sciences, Beijing, 100094, China. 'State Key Laboratory of Remote Sensing Science, Faculty of Geographical Science, Beijing Normal University, Beijing, 100875, China. 'Re-mail:[EMAIL_ADDRESS]
# [PERSON]
# 1 School of Geospatial Engineering and Science, SunYat-sen University & Southern Marine Science and Engineering Guangdong Laboratory (Zhuhai), Zhuhai, 519000, China. 'Key Laboratory of Comprehensive Observation of Polar Environment (SunYat-sen University), Ministry of Education, Zhuhai, 519000, China. 'Key Laboratory of Natural Resources Monitoring in Tropical and Subtropical area of South China, Ministry of natural resources, Zhuhai, 519000, China. 'Guangdong Provincial Key Laboratory of Geodynamics and Geohhazards, School of Earth Sciences and Engineering, Sun Yat-sen University, Zhuhai, 519000, China. 'State Key Laboratory of Remote Sensing Science, Aerospace Information Research Institute, Chinese Academy of Sciences, Beijing, 100094, China. 'State Key Laboratory of Remote Sensing Science, Faculty of Geographical Science, Beijing Normal University, Beijing, 100875, China. 'Re-mail:[EMAIL_ADDRESS]
# [PERSON]
# 1 School of Geospatial Engineering and Science, SunYat-sen University & Southern Marine Science and Engineering Guangdong Laboratory (Zhuhai), Zhuhai, 519000, China. 'Key Laboratory of Comprehensive Observation of Polar Environment (SunYat-sen University), Ministry of Education, Zhuhai, 519000, China. 'Key Laboratory of Natural Resources Monitoring in Tropical and Subtropical area of South China, Ministry of natural resources, Zhuhai, 519000, China. 'Guangdong Provincial Key Laboratory of Geodynamics and Geohhazards, School of Earth Sciences and Engineering, Sun Yat-sen University, Zhuhai, 519000, China. 'State Key Laboratory of Remote Sensing Science, Aerospace Information Research Institute, Chinese Academy of Sciences, Beijing, 100094, China. 'State Key Laboratory of Remote Sensing Science, Faculty of Geographical Science, Beijing Normal University, Beijing, 100875, China. 'Re-mail:[EMAIL_ADDRESS]
# [PERSON]
# 1 School of Geospatial Engineering and Science, SunYat-sen University & Southern Marine Science and Engineering Guangdong Laboratory (Zhuhai), Zhuhai, 519000, China. 'Key Laboratory of Comprehensive Observation of Polar Environment (SunYat-sen University), Ministry of Education, Zhuhai, 519000, China. 'Key Laboratory of Natural Resources Monitoring in Tropical and Subtropical area of South China, Ministry of natural resources, Zhuhai, 519000, China. 'Guangdong Provincial Key Laboratory of Geodynamics and Geohhazards, School of Earth Sciences and Engineering, Sun Yat-sen University, Zhuhai, 519000, China. 'State Key Laboratory of Remote Sensing Science, Aerospace Information Research Institute, Chinese Academy of Sciences, Beijing, 100094, China. 'State Key Laboratory of Remote Sensing Science, Faculty of Geographical Science, Beijing Normal University, Beijing, 100875, China. 'Re-mail:[EMAIL_ADDRESS]
#
# ────────────────────────────────────────────────────────────────────────
#   Document 3  |  Collection: EVE open access
# ────────────────────────────────────────────────────────────────────────
#   score           0.7042  [██████████████      ]
#                   ↳ cosine similarity query↔doc embedding (first-pass filter, ≥ 0.7 kept)
#   reranking_score 0.9911
#                   ↳ cross-encoder score; final ranking signal — higher = more relevant
#   text snippet    These estimates took into account both SBAF and BRDF correction. This paper proposes a technique to perform reflectance-based cross calibration between the Landsat 8 Operational Land Imager (OLI) and Sentinel 2A Multispectral Instrument (MSI) sensors with a proposed BRDF model, using coincident pairs of OLI and MSI images acquired over the Libya 4, Libya 1, Niger 2, and Sudan 1 North African Pseud…
#   metadata:
#     year: 2020
#     n_citations: 24
#     title: Radiometric Cross Calibration and Validation Using 4 Angle BRDF Model between Landsat 8 and Sentinel 2A
#     content: These estimates took into account both SBAF and BRDF correction. This paper proposes a technique to perform reflectance-based cross calibration between the Landsat 8 Operational Land Imager (OLI) and Sentinel 2A Multispectral Instrument (MSI) sensors with a proposed BRDF model, using coincident pairs of OLI and MSI images acquired over the Libya 4, Libya 1, Niger 2, and Sudan 1 North African Pseudo-Invariant Calibration Sites (PICS). This work also uses coincident/nearly coincident OLI-MSI image pairs acquired over Lake Tahoe and a volcano near the Libya 1 PICS as dark targets in order to incorporate a wider range of TOA reflectance values. In addition to providing a reasonable cross calibration between OLI and MSI, this work contributes to the ongoing process of \"harmonizing\" image data from current and future sensors. The paper is structured as follows. After a brief literature review, the methodology of the cross-calibration procedure is summarized. After that, results of the cross calibration are presented as are estimates of the associated individual and overall uncertainties. Then, an independent site is presented to validate the cross-calibration gains and biases. Finally, the Conclusion section summarizes the whole work and findings.
#     pipeline_metadata: {'pii_tokens_percentage': 0.0, 'newline_count': 0, 'word_count': 190}
#     publisher: MDPI AG
#     journal: Remote Sensing
#     headers: ['######Abstract']
#     url: https://doi.org/10.3390/rs12050806
#     file_path: mdpi/bcf06767-8d14-4461-a5b8-de452a2a5e43.pdf
#     doi: 10.3390/rs12050806
#
# ────────────────────────────────────────────────────────────────────────
#   Document 4  |  Collection: EVE open access
# ────────────────────────────────────────────────────────────────────────
#   score           0.7030  [██████████████      ]
#                   ↳ cosine similarity query↔doc embedding (first-pass filter, ≥ 0.7 kept)
#   reranking_score 0.9870
#                   ↳ cross-encoder score; final ranking signal — higher = more relevant
#   text snippet    ## 4 Conclusions   A new cross-calibration technique was developed for the Sentinel 2A MSI and Landsat 8 OLI sensors with the object of increasing data harmonization between them. The cross calibration was developed using reflectance data from Saharan Desert PICS and dark targets such as Lake Tahoe and the Libyan volcano. Specific uncertainties associated with each step of the proposed cross calib…
#   metadata:
#     doi: 10.3390/rs12050806
#     file_path: mdpi/bcf06767-8d14-4461-a5b8-de452a2a5e43.pdf
#     year: 2020
#     pipeline_metadata: {'newline_count': 1, 'pii_tokens_percentage': 0.0, 'word_count': 474}
#     n_citations: 24
#     journal: Remote Sensing
#     headers: ['##4 Conclusions']
#     content: ## 4 Conclusions
# A new cross-calibration technique was developed for the Sentinel 2A MSI and Landsat 8 OLI sensors with the object of increasing data harmonization between them. The cross calibration was developed using reflectance data from Saharan Desert PICS and dark targets such as Lake Tahoe and the Libyan volcano. Specific uncertainties associated with each step of the proposed cross calibration were estimated, as was the overall uncertainty associated with the entire process. Finally, the proposed cross calibration was validated using image data acquired over the Algodones Dunes site. For the blue band, the SBAF values for the desert PICS and Libyan volcanic site were within 3% to 4% of unity and within 8% of unity for Lake Tahoe for the blue band. For the other bands, the SBAF values were generally within 1% to 2% of unity. The proposed 4-angle BRDF normalization model demonstrated good potential for normalization in the longer wavelength bands but less potential for normalization in the coastal aerosol and blue bands. This can be explained by the fact that these bands are more sensitive to changes in atmospheric characteristics than direct changes in solar position. Though the relation of reflectance with respect to SZA and VZA is quadratic to maintain model and correction simplicity, the relationship was assumed to be linear. Not surprisingly, an extended version of the proposed four-angle model accounting for quadratic and interaction terms in SZA and VZA provided additional normalization, particularly in the shorter wavelength bands. Hence, researchers can use this model for a better understanding of the BRDF property of a surface. When cross-calibration gains and nonzero offsets are considered, the blue and red bands exhibited the largest deviations from unity gain, on the orders of \(-2.6\%\) and \(-1.44\%\), respectively. The coastal aerosol band was found to have the largest regression standard error (0.0326) and lowest corresponding R-square value (approximately 97%) for this parameter. With the exception of the blue band, the offset was not found to be statistically significant. When cross-calibration gains were considered with forced zero offsets, the blue band again exhibited the largest deviation from unity gain, on the order of 1.86%. Overall, the total uncertainty in the proposed cross calibration is approximately 6.8%. The largest contribution is due to the uncertainty in each sensor's calibration (on the order of 3% for OLI and of 5% for MSI). The next most significant sources contributing to the overall uncertainty were (i) differences in solar zenith and azimuth angles caused by the difference in local overpass times (on the order of 2.27%); (ii) site nonuniformity (on the order of 1.8%); (iii) differences in the sensor RSR measurement (on the order of 1% for MSI); (iv) potential shifts in spectral filter center wavelength and/or bandwidth (on the order of the 0.82% in the SWIR2 band); and (v) uncertainties in image registration error (on
#     title: Radiometric Cross Calibration and Validation Using 4 Angle BRDF Model between Landsat 8 and Sentinel 2A
#     url: https://doi.org/10.3390/rs12050806
#     publisher: MDPI AG
#
# ────────────────────────────────────────────────────────────────────────
#   Document 5  |  Collection: Wiley AI Gateway
# ────────────────────────────────────────────────────────────────────────
#   reranking_score 0.1210
#                   ↳ cross-encoder score; final ranking signal — higher = more relevant
#   text snippet    ## Materials and Methods  At the NLS, the adjustments were carried out in a local tangential coordinate system, and the data was subsequently converted to the ETRSTM35FIN coordinate system.  | ** | *FGI* | *NLS* | | --- | | Image coordinates, *x*, *y* (m) | 5 and 3 | 31 and 36^b^ | | GCP object coordinates, *X*, *Y*, *Z* (cm) | 2, 2, 2 | 2, 2, 2 | | GNSS/IMU positions, *X*~0~, *Y*~0~, *Z*~0~ (cm) …
#
# ────────────────────────────────────────────────────────────────────────
#   Document 6  |  Collection: Wiley AI Gateway
# ────────────────────────────────────────────────────────────────────────
#   reranking_score 0.1065
#                   ↳ cross-encoder score; final ranking signal — higher = more relevant
#   text snippet    ##  calibration of microelectrode  The microelectrode was calibrated using a FAST16 electrochemical recording system (Quanteon, LLC, Nicholesville, KY, USA) prior to implantation in animals. Constant voltage amperometry was used, with a potential of +0.7V applied vs. an Ag/AgCl reference electrode. Calibration was performed in a stirred solution of 0.05m PBS (40mL) at 37C. After 1520min, to allow …
#
# ────────────────────────────────────────────────────────────────────────
#   Document 7  |  Collection: Wiley AI Gateway
# ────────────────────────────────────────────────────────────────────────
#   reranking_score 0.3854
#                   ↳ cross-encoder score; final ranking signal — higher = more relevant
#   text snippet    As discussed earlier, the fact that the calibration coefficients from prelaunch WUCD deviated from those from the BCS prelaunch already showed differences in the calibration curve shape between the two. Naturally, the onorbitderived calibration coefficients from WUCD cannot be expected to match those from the prelaunch BCS tests.
#
# ────────────────────────────────────────────────────────────────────────
#   Document 8  |  Collection: Wiley AI Gateway
# ────────────────────────────────────────────────────────────────────────
#   reranking_score 0.4834
#                   ↳ cross-encoder score; final ranking signal — higher = more relevant
#   text snippet    ## II. MATERIALS AND METHODS  The software is able to trigger on different events such as inspirationpeak, expirationpeak or derived events, so that the system can be classified as a phasebased triggering system ([Fig. 1(a)](#acm20334-fig-0001)).  The Sentinel system consists of a laser which sweeps within a few seconds over the surface of the patient and a camera to detect the laser projections (…
#
# ────────────────────────────────────────────────────────────────────────
#   Document 9  |  Collection: Wiley AI Gateway
# ────────────────────────────────────────────────────────────────────────
#   reranking_score 0.1430
#                   ↳ cross-encoder score; final ranking signal — higher = more relevant
#   text snippet    ## Acknowledgements  We thank R. Brans, I. Carati, X. Chitnis, M. Langen, and T. van Raalten for their assistance in the calibration study.
#
# ────────────────────────────────────────────────────────────────────────
#   Document 10  |  Collection: Wiley AI Gateway
# ────────────────────────────────────────────────────────────────────────
#   reranking_score 0.7793
#                   ↳ cross-encoder score; final ranking signal — higher = more relevant
#   text snippet    ## 4. Result Analysis and Discussion  Sentinel 2 satellite imageries were selected to evaluate their suitability for investigating water quality in inland water. Sentinel 2 images were obtained from the European Space Agency through Copernicus Open Access Hub ([https://scihub.copernicus.eu](https://scihub.copernicus.eu/)). Three images of level1C (L1C) MSI data were used in this study. Table [4](#…

# %%
retrieved
# Out:
# {'retrieved_docs': [{'id': '8585537289369820823',
#    'version': 18514,
#    'score': 0.7254181,
#    'reranking_score': 0.9960540533065796,
#    'collection_name': 'EVE open access',
#    'payload': {'journal': 'Remote Sensing',
#     'headers': ['######Abstract'],
#     'citation_count': 0,
#     'title': 'Observations and Recommendations for the Calibration of Landsat 8 OLI and Sentinel 2 MSI for Improved Data Interoperability',
#     'file_path': 'mdpi/2633df9a_d147_4da5_995a_b9bea788d323.md',
#     'year': 2018,
#     'content': 'An outline of calibration procedures for Landsat and Sentinel 2 is provided with extensive references to detailed information for the interested reader. After this introduction to the sensors, a calibration comparison of the two instruments is presented. The next section of the paper presents the current status and limitations of data operability with these sensors based on four perspectives. Lastly, the recommendations produced by the panel are presented and the paper closes with a short summary.',
#     'url': 'https://doi.org/10.3390/rs10091340',
#     'n_citations': '62',
#     'publisher': 'MDPI AG',
#     'authors': 'Dennis Helder, Brian Markham, Ron Morfitt, Jim Storey, Julia Barsi, Ferran Gascon, Sebastien Clerc, Bruno LaFrance, Jeff Masek, David P. Roy, Adam Lewis, Nima Pahlevan',
#     'pipeline_metadata': {'newline_count': 0,
#      'word_count': 76,
#      'pii_tokens_percentage': 0.0},
#     'doi': '10.3390/rs10091340',
#     'id': 265775},
#    'text': 'An outline of calibration procedures for Landsat and Sentinel 2 is provided with extensive references to detailed information for the interested reader. After this introduction to the sensors, a calibration comparison of the two instruments is presented. The next section of the paper presents the current status and limitations of data operability with these sensors based on four perspectives. Lastly, the recommendations produced by the panel are presented and the paper closes with a short summary.',
#    'metadata': {}},
#   {'id': '5988692620620791814',
#    'version': 16952,
#    'score': 0.7154861,
#    'reranking_score': 0.0021805083379149437,
#    'collection_name': 'EVE open access',
#    'payload': {'year': 2024,
#     'file_path': 'ncbi/debaec5e-1da0-45b0-88bf-3f7a8360f484.pdf',
#     'n_citations': '0',
#     'title': 'A dataset of topographic correction coefficients for shortwave downward radiation over the Pan-Third Pole',
#     'doi': '10.1038/s41597-024-03616-2',
#     'publisher': 'Springer Science and Business Media LLC',
#     'url': 'https://doi.org/10.1038/s41597-024-03616-2',
#     'journal': 'Scientific Data',
#     'headers': ['#Scientific data'],
#     'pipeline_metadata': {'pii_tokens_percentage': 0.016736401673640166,
#      'word_count': 478,
#      'newline_count': 9},
#     'content': "# Scientific data  \nOpen A dataset of topographic correction coefficients for shortwave downward radiation over the Pan-Third Pole  \n[PERSON]  \n1 School of Geospatial Engineering and Science, SunYat-sen University & Southern Marine Science and Engineering Guangdong Laboratory (Zhuhai), Zhuhai, 519000, China. 'Key Laboratory of Comprehensive Observation of Polar Environment (SunYat-sen University), Ministry of Education, Zhuhai, 519000, China. 'Key Laboratory of Natural Resources Monitoring in Tropical and Subtropical area of South China, Ministry of natural resources, Zhuhai, 519000, China. 'Guangdong Provincial Key Laboratory of Geodynamics and Geohhazards, School of Earth Sciences and Engineering, Sun Yat-sen University, Zhuhai, 519000, China. 'State Key Laboratory of Remote Sensing Science, Aerospace Information Research Institute, Chinese Academy of Sciences, Beijing, 100094, China. 'State Key Laboratory of Remote Sensing Science, Faculty of Geographical Science, Beijing Normal University, Beijing, 100875, China. 'Re-mail:[EMAIL_ADDRESS]  \n[PERSON]  \n1 School of Geospatial Engineering and Science, SunYat-sen University & Southern Marine Science and Engineering Guangdong Laboratory (Zhuhai), Zhuhai, 519000, China. 'Key Laboratory of Comprehensive Observation of Polar Environment (SunYat-sen University), Ministry of Education, Zhuhai, 519000, China. 'Key Laboratory of Natural Resources Monitoring in Tropical and Subtropical area of South China, Ministry of natural resources, Zhuhai, 519000, China. 'Guangdong Provincial Key Laboratory of Geodynamics and Geohhazards, School of Earth Sciences and Engineering, Sun Yat-sen University, Zhuhai, 519000, China. 'State Key Laboratory of Remote Sensing Science, Aerospace Information Research Institute, Chinese Academy of Sciences, Beijing, 100094, China. 'State Key Laboratory of Remote Sensing Science, Faculty of Geographical Science, Beijing Normal University, Beijing, 100875, China. 'Re-mail:[EMAIL_ADDRESS]  \n[PERSON]  \n1 School of Geospatial Engineering and Science, SunYat-sen University & Southern Marine Science and Engineering Guangdong Laboratory (Zhuhai), Zhuhai, 519000, China. 'Key Laboratory of Comprehensive Observation of Polar Environment (SunYat-sen University), Ministry of Education, Zhuhai, 519000, China. 'Key Laboratory of Natural Resources Monitoring in Tropical and Subtropical area of South China, Ministry of natural resources, Zhuhai, 519000, China. 'Guangdong Provincial Key Laboratory of Geodynamics and Geohhazards, School of Earth Sciences and Engineering, Sun Yat-sen University, Zhuhai, 519000, China. 'State Key Laboratory of Remote Sensing Science, Aerospace Information Research Institute, Chinese Academy of Sciences, Beijing, 100094, China. 'State Key Laboratory of Remote Sensing Science, Faculty of Geographical Science, Beijing Normal University, Beijing, 100875, China. 'Re-mail:[EMAIL_ADDRESS]  \n[PERSON]  \n1 School of Geospatial Engineering and Science, SunYat-sen University & Southern Marine Science and Engineering Guangdong Laboratory (Zhuhai), Zhuhai, 519000, China. 'Key Laboratory of Comprehensive Observation of Polar Environment (SunYat-sen University), Ministry of Education, Zhuhai, 519000, China. 'Key Laboratory of Natural Resources Monitoring in Tropical and Subtropical area of South China, Ministry of natural resources, Zhuhai, 519000, China. 'Guangdong Provincial Key Laboratory of Geodynamics and Geohhazards, School of Earth Sciences and Engineering, Sun Yat-sen University, Zhuhai, 519000, China. 'State Key Laboratory of Remote Sensing Science, Aerospace Information Research Institute, Chinese Academy of Sciences, Beijing, 100094, China. 'State Key Laboratory of Remote Sensing Science, Faculty of Geographical Science, Beijing Normal University, Beijing, 100875, China. 'Re-mail:[EMAIL_ADDRESS]"},
#    'text': "# Scientific data  \nOpen A dataset of topographic correction coefficients for shortwave downward radiation over the Pan-Third Pole  \n[PERSON]  \n1 School of Geospatial Engineering and Science, SunYat-sen University & Southern Marine Science and Engineering Guangdong Laboratory (Zhuhai), Zhuhai, 519000, China. 'Key Laboratory of Comprehensive Observation of Polar Environment (SunYat-sen University), Ministry of Education, Zhuhai, 519000, China. 'Key Laboratory of Natural Resources Monitoring in Tropical and Subtropical area of South China, Ministry of natural resources, Zhuhai, 519000, China. 'Guangdong Provincial Key Laboratory of Geodynamics and Geohhazards, School of Earth Sciences and Engineering, Sun Yat-sen University, Zhuhai, 519000, China. 'State Key Laboratory of Remote Sensing Science, Aerospace Information Research Institute, Chinese Academy of Sciences, Beijing, 100094, China. 'State Key Laboratory of Remote Sensing Science, Faculty of Geographical Science, Beijing Normal University, Beijing, 100875, China. 'Re-mail:[EMAIL_ADDRESS]  \n[PERSON]  \n1 School of Geospatial Engineering and Science, SunYat-sen University & Southern Marine Science and Engineering Guangdong Laboratory (Zhuhai), Zhuhai, 519000, China. 'Key Laboratory of Comprehensive Observation of Polar Environment (SunYat-sen University), Ministry of Education, Zhuhai, 519000, China. 'Key Laboratory of Natural Resources Monitoring in Tropical and Subtropical area of South China, Ministry of natural resources, Zhuhai, 519000, China. 'Guangdong Provincial Key Laboratory of Geodynamics and Geohhazards, School of Earth Sciences and Engineering, Sun Yat-sen University, Zhuhai, 519000, China. 'State Key Laboratory of Remote Sensing Science, Aerospace Information Research Institute, Chinese Academy of Sciences, Beijing, 100094, China. 'State Key Laboratory of Remote Sensing Science, Faculty of Geographical Science, Beijing Normal University, Beijing, 100875, China. 'Re-mail:[EMAIL_ADDRESS]  \n[PERSON]  \n1 School of Geospatial Engineering and Science, SunYat-sen University & Southern Marine Science and Engineering Guangdong Laboratory (Zhuhai), Zhuhai, 519000, China. 'Key Laboratory of Comprehensive Observation of Polar Environment (SunYat-sen University), Ministry of Education, Zhuhai, 519000, China. 'Key Laboratory of Natural Resources Monitoring in Tropical and Subtropical area of South China, Ministry of natural resources, Zhuhai, 519000, China. 'Guangdong Provincial Key Laboratory of Geodynamics and Geohhazards, School of Earth Sciences and Engineering, Sun Yat-sen University, Zhuhai, 519000, China. 'State Key Laboratory of Remote Sensing Science, Aerospace Information Research Institute, Chinese Academy of Sciences, Beijing, 100094, China. 'State Key Laboratory of Remote Sensing Science, Faculty of Geographical Science, Beijing Normal University, Beijing, 100875, China. 'Re-mail:[EMAIL_ADDRESS]  \n[PERSON]  \n1 School of Geospatial Engineering and Science, SunYat-sen University & Southern Marine Science and Engineering Guangdong Laboratory (Zhuhai), Zhuhai, 519000, China. 'Key Laboratory of Comprehensive Observation of Polar Environment (SunYat-sen University), Ministry of Education, Zhuhai, 519000, China. 'Key Laboratory of Natural Resources Monitoring in Tropical and Subtropical area of South China, Ministry of natural resources, Zhuhai, 519000, China. 'Guangdong Provincial Key Laboratory of Geodynamics and Geohhazards, School of Earth Sciences and Engineering, Sun Yat-sen University, Zhuhai, 519000, China. 'State Key Laboratory of Remote Sensing Science, Aerospace Information Research Institute, Chinese Academy of Sciences, Beijing, 100094, China. 'State Key Laboratory of Remote Sensing Science, Faculty of Geographical Science, Beijing Normal University, Beijing, 100875, China. 'Re-mail:[EMAIL_ADDRESS]",
#    'metadata': {}},
#   {'id': '8864110219032621577',
#    'version': 18738,
#    'score': 0.704174,
#    'reranking_score': 0.9911444783210754,
#    'collection_name': 'EVE open access',
#    'payload': {'year': 2020,
#     'n_citations': '24',
#     'title': 'Radiometric Cross Calibration and Validation Using 4 Angle BRDF Model between Landsat 8 and Sentinel 2A',
#     'content': 'These estimates took into account both SBAF and BRDF correction. This paper proposes a technique to perform reflectance-based cross calibration between the Landsat 8 Operational Land Imager (OLI) and Sentinel 2A Multispectral Instrument (MSI) sensors with a proposed BRDF model, using coincident pairs of OLI and MSI images acquired over the Libya 4, Libya 1, Niger 2, and Sudan 1 North African Pseudo-Invariant Calibration Sites (PICS). This work also uses coincident/nearly coincident OLI-MSI image pairs acquired over Lake Tahoe and a volcano near the Libya 1 PICS as dark targets in order to incorporate a wider range of TOA reflectance values. In addition to providing a reasonable cross calibration between OLI and MSI, this work contributes to the ongoing process of \\"harmonizing\\" image data from current and future sensors. The paper is structured as follows. After a brief literature review, the methodology of the cross-calibration procedure is summarized. After that, results of the cross calibration are presented as are estimates of the associated individual and overall uncertainties. Then, an independent site is presented to validate the cross-calibration gains and biases. Finally, the Conclusion section summarizes the whole work and findings.',
#     'pipeline_metadata': {'pii_tokens_percentage': 0.0,
#      'newline_count': 0,
#      'word_count': 190},
#     'publisher': 'MDPI AG',
#     'journal': 'Remote Sensing',
#     'headers': ['######Abstract'],
#     'url': 'https://doi.org/10.3390/rs12050806',
#     'file_path': 'mdpi/bcf06767-8d14-4461-a5b8-de452a2a5e43.pdf',
#     'doi': '10.3390/rs12050806'},
#    'text': 'These estimates took into account both SBAF and BRDF correction. This paper proposes a technique to perform reflectance-based cross calibration between the Landsat 8 Operational Land Imager (OLI) and Sentinel 2A Multispectral Instrument (MSI) sensors with a proposed BRDF model, using coincident pairs of OLI and MSI images acquired over the Libya 4, Libya 1, Niger 2, and Sudan 1 North African Pseudo-Invariant Calibration Sites (PICS). This work also uses coincident/nearly coincident OLI-MSI image pairs acquired over Lake Tahoe and a volcano near the Libya 1 PICS as dark targets in order to incorporate a wider range of TOA reflectance values. In addition to providing a reasonable cross calibration between OLI and MSI, this work contributes to the ongoing process of \\"harmonizing\\" image data from current and future sensors. The paper is structured as follows. After a brief literature review, the methodology of the cross-calibration procedure is summarized. After that, results of the cross calibration are presented as are estimates of the associated individual and overall uncertainties. Then, an independent site is presented to validate the cross-calibration gains and biases. Finally, the Conclusion section summarizes the whole work and findings.',
#    'metadata': {}},
#   {'id': '13715297977963934963',
#    'version': 33864,
#    'score': 0.70297295,
#    'reranking_score': 0.9870126843452454,
#    'collection_name': 'EVE open access',
#    'payload': {'doi': '10.3390/rs12050806',
#     'file_path': 'mdpi/bcf06767-8d14-4461-a5b8-de452a2a5e43.pdf',
#     'year': 2020,
#     'pipeline_metadata': {'newline_count': 1,
#      'pii_tokens_percentage': 0.0,
#      'word_count': 474},
#     'n_citations': '24',
#     'journal': 'Remote Sensing',
#     'headers': ['##4 Conclusions'],
#     'content': "## 4 Conclusions  \nA new cross-calibration technique was developed for the Sentinel 2A MSI and Landsat 8 OLI sensors with the object of increasing data harmonization between them. The cross calibration was developed using reflectance data from Saharan Desert PICS and dark targets such as Lake Tahoe and the Libyan volcano. Specific uncertainties associated with each step of the proposed cross calibration were estimated, as was the overall uncertainty associated with the entire process. Finally, the proposed cross calibration was validated using image data acquired over the Algodones Dunes site. For the blue band, the SBAF values for the desert PICS and Libyan volcanic site were within 3% to 4% of unity and within 8% of unity for Lake Tahoe for the blue band. For the other bands, the SBAF values were generally within 1% to 2% of unity. The proposed 4-angle BRDF normalization model demonstrated good potential for normalization in the longer wavelength bands but less potential for normalization in the coastal aerosol and blue bands. This can be explained by the fact that these bands are more sensitive to changes in atmospheric characteristics than direct changes in solar position. Though the relation of reflectance with respect to SZA and VZA is quadratic to maintain model and correction simplicity, the relationship was assumed to be linear. Not surprisingly, an extended version of the proposed four-angle model accounting for quadratic and interaction terms in SZA and VZA provided additional normalization, particularly in the shorter wavelength bands. Hence, researchers can use this model for a better understanding of the BRDF property of a surface. When cross-calibration gains and nonzero offsets are considered, the blue and red bands exhibited the largest deviations from unity gain, on the orders of \\(-2.6\\%\\) and \\(-1.44\\%\\), respectively. The coastal aerosol band was found to have the largest regression standard error (0.0326) and lowest corresponding R-square value (approximately 97%) for this parameter. With the exception of the blue band, the offset was not found to be statistically significant. When cross-calibration gains were considered with forced zero offsets, the blue band again exhibited the largest deviation from unity gain, on the order of 1.86%. Overall, the total uncertainty in the proposed cross calibration is approximately 6.8%. The largest contribution is due to the uncertainty in each sensor's calibration (on the order of 3% for OLI and of 5% for MSI). The next most significant sources contributing to the overall uncertainty were (i) differences in solar zenith and azimuth angles caused by the difference in local overpass times (on the order of 2.27%); (ii) site nonuniformity (on the order of 1.8%); (iii) differences in the sensor RSR measurement (on the order of 1% for MSI); (iv) potential shifts in spectral filter center wavelength and/or bandwidth (on the order of the 0.82% in the SWIR2 band); and (v) uncertainties in image registration error (on",
#     'title': 'Radiometric Cross Calibration and Validation Using 4 Angle BRDF Model between Landsat 8 and Sentinel 2A',
#     'url': 'https://doi.org/10.3390/rs12050806',
#     'publisher': 'MDPI AG'},
#    'text': "## 4 Conclusions  \nA new cross-calibration technique was developed for the Sentinel 2A MSI and Landsat 8 OLI sensors with the object of increasing data harmonization between them. The cross calibration was developed using reflectance data from Saharan Desert PICS and dark targets such as Lake Tahoe and the Libyan volcano. Specific uncertainties associated with each step of the proposed cross calibration were estimated, as was the overall uncertainty associated with the entire process. Finally, the proposed cross calibration was validated using image data acquired over the Algodones Dunes site. For the blue band, the SBAF values for the desert PICS and Libyan volcanic site were within 3% to 4% of unity and within 8% of unity for Lake Tahoe for the blue band. For the other bands, the SBAF values were generally within 1% to 2% of unity. The proposed 4-angle BRDF normalization model demonstrated good potential for normalization in the longer wavelength bands but less potential for normalization in the coastal aerosol and blue bands. This can be explained by the fact that these bands are more sensitive to changes in atmospheric characteristics than direct changes in solar position. Though the relation of reflectance with respect to SZA and VZA is quadratic to maintain model and correction simplicity, the relationship was assumed to be linear. Not surprisingly, an extended version of the proposed four-angle model accounting for quadratic and interaction terms in SZA and VZA provided additional normalization, particularly in the shorter wavelength bands. Hence, researchers can use this model for a better understanding of the BRDF property of a surface. When cross-calibration gains and nonzero offsets are considered, the blue and red bands exhibited the largest deviations from unity gain, on the orders of \\(-2.6\\%\\) and \\(-1.44\\%\\), respectively. The coastal aerosol band was found to have the largest regression standard error (0.0326) and lowest corresponding R-square value (approximately 97%) for this parameter. With the exception of the blue band, the offset was not found to be statistically significant. When cross-calibration gains were considered with forced zero offsets, the blue band again exhibited the largest deviation from unity gain, on the order of 1.86%. Overall, the total uncertainty in the proposed cross calibration is approximately 6.8%. The largest contribution is due to the uncertainty in each sensor's calibration (on the order of 3% for OLI and of 5% for MSI). The next most significant sources contributing to the overall uncertainty were (i) differences in solar zenith and azimuth angles caused by the difference in local overpass times (on the order of 2.27%); (ii) site nonuniformity (on the order of 1.8%); (iii) differences in the sensor RSR measurement (on the order of 1% for MSI); (iv) potential shifts in spectral filter center wavelength and/or bandwidth (on the order of the 0.82% in the SWIR2 band); and (v) uncertainties in image registration error (on",
#    'metadata': {}},
#   {'id': '10.1111/j.1477-9730.2011.00634.x_0009',
#    'version': None,
#    'score': None,
#    'reranking_score': 0.12104737013578415,
#    'collection_name': 'Wiley AI Gateway',
#    'payload': {},
#    'text': '## Materials and Methods\n\nAt the NLS, the adjustments were carried out in a local tangential coordinate system, and the data was subsequently converted to the ETRSTM35FIN coordinate system.\n\n| ** | *FGI* | *NLS* |\n| --- |\n| Image coordinates, *x*, *y* (m) | 5 and 3 | 31 and 36^b^ |\n| GCP object coordinates, *X*, *Y*, *Z* (cm) | 2, 2, 2 | 2, 2, 2 |\n| GNSS/IMU positions, *X*~0~, *Y*~0~, *Z*~0~ (cm) | 3839^a^ | 1618, 3441, 4042^b^ |\n| GNSS/IMU attitudes, **, **, ** (mgon) | 45, 45, 1418^a^ | 3746, 2329, 4870^b^ |\n{#t2}\n\nThe analysis of radiometric performance included the evaluation of the system and the output products.\n\nA total of eight artificial reflectance reference targets were used to provide ground truth: white, grey and three black gravel targets and three portable painted tarpaulins ([Fig.2(a)](#f2)), providing a reflectance range of 005 to 050. BRFs of the targets have been measured in a laboratory using a FIGIFIGO goniospectrometer ([Suomalainen et al., 2009](#b36)) and their nadir reflectance spectra were measured during the 1st September campaign using a spectroradiometer ([Markelin et al., 2010b](#b30)).\n\n**2**\n\n*(a) Sjkulla radiometric and spatial resolution testfield. B1, B2a, B2b: black gravels. R1: red gravel. G2: grey gravel. W2: white gravel. P20, P30, P50: portable reflectance targets with 020, 030 and 050 nominal reflectance. (b) Distribution of radiometric and resolution targets on the focal plane on 1st and 25th September data. The arrow shows the flying direction.*\n{#f2}\n\nThe assessment of the system included analysis of vicarious calibration, linearity of sensor response, dynamic range and sensor stability. The MODTRAN4 software was used to convert the target reflectance spectra to atsensor radiances for the purposes of vicarious calibration. Only images where the reflectance targets were located in the nadir region of the images were used (altogether nine images). Details of the processing are given by [Markelin et al. (2010b)](#b30).\n\nThe radiometric output products requested by the users are the true colour and reflectance images ([Honkavaara et al., 2009](#b19)); in this contribution the extraction of multidirectional reflectance data was considered. An empirical linebased method was used, modified to take into account the anisotropy of the object, to perform the atmospheric correction ([Smith and Milton, 1999](#b34)): 1 where **~*i*~ and **~*i*~ are azimuth and zenith angles of the illumination and **~*r*~ and **~*r*~ are azimuth and zenith angles of the reflected light ([SchaepmanStrub et al., 2006](#b32); [Suomalainen et al., 2009](#b36)). Here *R*~*s*~(**~*i*~,**~*i*~,**~*r*~,**~*r*~) is the BRF and *a*(**~*i*~,**~*i*~,**~*r*~,**~*r*~) and *b*(**~*i*~,**~*i*~,**~*r*~,**~*r*~) are the parameters of the linear calibration model for the specific illumination and observation geometry, *DN* is the digital grey value. The black gravel (nominal reflectance 005) and bright painted tarpaulin (nominal reflectance 020 and 030 on 1st and 25th September, respectively) were used as the calibration reference; the other six targets were used as check targets (if not overexposed). In this case the calibration was calculated for each image separately. This process relates the airborne measurements to the BRF measurements in a laboratory. Altogether 32 images on 1st September and 18 images on 25th September were used in the evaluation. The positions of the targets on the focal plane are shown in [Fig.2(b)](#f2).\n\nThese steps could not be carried out from a fully operational point of view, as the sensor was not absolutely calibrated and the production line does not produce the desired outputs.',
#    'metadata': {'journal_code': '14779730',
#     'article_type': 'article',
#     'pub_type': 'article',
#     'journal_issn': '1477-9730',
#     'additionalMetadata': {'volume': '26',
#      'pageRange': '229-249',
#      'citationLine': 'Honkavaara, E., Nurminen, K., Markelin, L., Suomalainen, J., & Ilves, R. (2011). Calibrating and validating multispectral 3D imaging systems at a permanent test site—case study with an Intergraph DMC. The Photogrammetric Record, 26(134), 229-249. https://doi.org/10.1111/j.1477-9730.2011.00634.x',
#      'issue': '134',
#      'link': 'https://doi.org/10.1111/j.1477-9730.2011.00634.x',
#      'isRetracted': False,
#      'publisher': 'John Wiley & Sons, Ltd',
#      'abstract': 'Abstract \nNovel photogrammetric sensors open up new possibilities for measuring the radiometric and geometric properties of the earth’s surface. To ensure optimal use of these complex, rapidly developing, diverse systems, it is becoming crucial to have a means of calibrating and validating complete imaging systems, and even production lines, in operational conditions. This paper presents a calibration and validation methodology based on a permanent test site (Sjökulla) and demonstrates its use in a calibration and validation campaign for a large‐format photogrammetric imaging system, the Intergraph DMC. The major objective of the campaign was to perform acceptance testing of the new camera system procured by the National Land Survey of Finland. The evaluation proved the high geometric and radiometric performance of the imaging system and demonstrated the potential of spectrodirectional photogrammetric 3D imaging. The usability aspects of test site calibration and validation from the point of view of a mapping organisation were also considered.\n\nRésumé \nLes capteurs photogrammétriques actuels ouvrent de nouvelles possibilités pour mesurer les propriétés radiométriques et géométriques de la surface terrestre. Pour garantir une utilisation optimale de systèmes variés, évolutifs et complexes, il devient indispensable d’avoir les moyens d’étalonner et de valider des systèmes imageurs complets, voire des lignes de production dans des conditions opérationnelles. Cet article présente les résultats d’une campagne d’étalonnage et de validation pour une caméra Intergraph DMC grand format sur un site test permanent, Sjökulla. L’objectif principal de la campagne était de réaliser des tests de conformité pour la nouvelle caméra du National Land Survey de Finlande. L’évaluation a permis de vérifier les hautes performances géométriques et radiométriques de la caméra et de montrer le potentiel de l’imagerie spectrodirectionnelle photogrammétrique 3D. Les chercheurs ont également considéré les aspects liés à l’utilisation pratique d’un site d’étalonnage et de validation du point de vue d’une agence de cartographie.\n\nZusammenfassung \nNeuartige photogrammetrische Sensoren eröffnen neue Möglichkeiten, die radiometrischen und geometrischen Eigenschaften der Erdoberfläche zu erfassen. Um eine optimale Nutzung der komplexen, rasch weiterentwickelten und sehr diversen Systeme zu ermöglichen, müssen Mittel zur Kalibrierung und Validierung kompletter abbildender Systeme, bzw. sogar kompletter Prozesse unter operationellen Bedingungen zur Verfügung stehen. Dieser Beitrag präsentiert Ergebnisse einer Kampagne zur Kalibrierung und Validierung einer Intergraph DMC, einem photogrammetrischen Bildaufnahmesystem, auf dem permanenten Testgebiet Sjökulla. Der Hauptzweck der Untersuchung war eine Akzeptanztest des neuen Kamerasystems, das von der Landesvermessungsbehörde National Land Survey of Finland beschafft wurde. Die Auswertung bestätigte die hohe geometrische und radiometrische Qua‐lität des Kamerasystems und demonstrierte das Potential zur dreidimensionalen photogrammetrischen spektraldirektionalen Aufnahme. Aus der Sicht einer Ver‐messungsbehörde wurden auch die Anwendungsaspekte einer Testfeldkalibrierung und ‐validierung untersucht.\n\nResumen \nLos nuevos sensores fotogramétricos abren nuevas oportunidades para medir las propiedades radiométricas y geométricas de la superficie de la tierra. Para hacer un uso óptimo de los diversos, complejos y rápidamente cambiantes sistemas, es crucial disponer de medios para calibrar y validar los sistemas de imagen completos, o incluso líneas de producción, en condiciones operativas. Este artículo presenta los resultados de una campaña de calibración y validación del sistema de imagen fotogramétrico de gran formato Intergraph DMC llevada a cabo en el campo permanente de pruebas de Sjökulla. El principal objetivo de la campaña fue realizar la prueba de aceptación de la nueva cámara del Natio ...
#      'title': 'Calibrating and validating multispectral 3D imaging systems at a permanent test site—case study with an Intergraph DMC',
#      'isOpenAccess': False,
#      'publicationDate': '06 June 2011',
#      'journalTitle': 'The Photogrammetric Record'},
#     'total_chunks': 22}},
#   {'id': '10.1111/j.1460-9568.2004.03614.x_0004',
#    'version': None,
#    'score': None,
#    'reranking_score': 0.10647846013307571,
#    'collection_name': 'Wiley AI Gateway',
#    'payload': {},
#    'text': '##  calibration of microelectrode\n\nThe microelectrode was calibrated using a FAST16 electrochemical recording system (Quanteon, LLC, Nicholesville, KY, USA) prior to implantation in animals. Constant voltage amperometry was used, with a potential of +0.7V applied vs. an Ag/AgCl reference electrode. Calibration was performed in a stirred solution of 0.05m PBS (40mL) at 37C. After 1520min, to allow for a stable baseline, aliquots of stock solutions of AA (20mm), choline (20mm) and DA (2mm) were added to the calibration beaker such that the final concentrations were 250m AA, 10, 20, 30 and 40m choline, and 2m DA. The slope, limit of detection (LOD) and linearity (R^2^) for choline, as well as selectivity ratios for AA and DA, were calculated. Changes in current that reflect the oxidation of choline were assessed using a selfreferencing procedure. In this procedure, responses from the individual channels coated with CO were normalized by dividing the current by the microelectrode response obtained following the addition of DA and then by subtracting the background current from sentinel channels. This procedure increases the signaltonoise ratio and subsequent limit of detection for choline. Calibration data from both the choline and sentinel recording channels were transformed in this fashion before the selectivity, slope, LOD and R^2^ were recalculated.',
#    'metadata': {'journal_code': '14609568',
#     'article_type': 'article',
#     'pub_type': 'article',
#     'journal_issn': '1460-9568',
#     'additionalMetadata': {'volume': '20',
#      'pageRange': '1545-1554',
#      'citationLine': 'Parikh, V., Pomerleau, F., Huettl, P., Gerhardt, G. A., Sarter, M., & Bruno, J. P. (2004). Rapid assessment of in vivo cholinergic transmission by amperometric detection of changes in extracellular choline levels. European Journal of Neuroscience, 20(6), 1545-1554. https://doi.org/10.1111/j.1460-9568.2004.03614.x',
#      'issue': '6',
#      'link': 'https://doi.org/10.1111/j.1460-9568.2004.03614.x',
#      'isRetracted': False,
#      'publisher': 'John Wiley & Sons, Ltd',
#      'abstract': 'Abstract \nConventional microdialysis methods for measuring acetylcholine (ACh) efflux do not provide sufficient temporal resolution to relate cholinergic transmission to individual stimuli or behavioral responses, or sufficient spatial resolution to investigate heterogeneities in such regulation within a brain region. In an effort to overcome these constraints, we investigated a ceramic‐based microelectrode array designed to measure amperometrically rapid changes in extracellular choline as a marker for cholinergic transmission in the frontoparietal cortex of anesthetized rats. These microelectrodes exhibited detection limits of 300\u2003nm for choline and selectivity (>\u2003100\u2003:\u20031) of choline over interferents such as ascorbic acid. Intracortical pressure ejections of choline (20\u2003mm, 66–400\u2003nL) and ACh (10 and 100\u2003mm, 200\u2003nL) dose‐dependently increased choline‐related signals that were cleared to background levels within 10\u2003s. ACh, but not choline‐induced signals, were significantly attenuated by co‐ejection of the acetylcholinesterase inhibitor neostigmine (Neo; 100\u2003mm). Pressure ejections of drugs known to increase cortical ACh efflux, potassium (KCl; 70\u2003mm, 66, 200\u2003nL) and scopolamine (Scop; 10\u2003mm, 200\u2003nL), also markedly increased extracellular choline signals, which again were inhibited by Neo. Scop‐induced choline signals were also found to be tetrodotoxin‐sensitive. Collectively, these findings suggest that drug‐induced increases in current measured with these microelectrode arrays reflect the oxidation of choline that is neuronally derived from the release and subsequent hydrolysis of ACh. Choline signals assessed using enzyme‐selective microelectrode arrays may represent a rapid, sensitive and spatially discrete measure of cholinergic transmission.\n\n',
#      'title': 'Rapid assessment of in vivo cholinergic transmission by amperometric detection of changes in extracellular choline levels',
#      'isOpenAccess': False,
#      'publicationDate': '06 September 2004',
#      'journalTitle': 'European Journal of Neuroscience'},
#     'total_chunks': 18}},
#   {'id': '10.1002/2017JD026590_0010',
#    'version': None,
#    'score': None,
#    'reranking_score': 0.3854411244392395,
#    'collection_name': 'Wiley AI Gateway',
#    'payload': {},
#    'text': 'As discussed earlier, the fact that the calibration coefficients from prelaunch WUCD deviated from those from the BCS prelaunch already showed differences in the calibration curve shape between the two. Naturally, the onorbitderived calibration coefficients from WUCD cannot be expected to match those from the prelaunch BCS tests.',
#    'metadata': {'journal_code': '21698996',
#     'article_type': 'article',
#     'pub_type': 'article',
#     'journal_issn': '2169-8996',
#     'additionalMetadata': {'volume': '122',
#      'pageRange': '5285-5297',
#      'citationLine': 'Cao, C., Wang, W., Blonski, S., & Zhang, B. (2017). Radiometric traceability diagnosis and bias correction for the Suomi NPP VIIRS long‐wave infrared channels during blackbody unsteady states. Journal of Geophysical Research: Atmospheres, 122(10), 5285-5297. https://doi.org/10.1002/2017JD026590',
#      'issue': '10',
#      'link': 'https://doi.org/10.1002/2017JD026590',
#      'isRetracted': False,
#      'publisher': 'John Wiley & Sons, Ltd',
#      'abstract': 'Abstract \nThe Suomi National Polar‐orbiting Partnership Program (NPP) Visible Infrared Imaging Radiometer Suite (VIIRS) Thermal Emissive Bands (TEBs) have been performing well since the data became available on 20 January 2012, and the Sensor Data Record data reached validated maturity on 18 March 2014. While overall the validation has shown that these channels have an estimated absolute uncertainty on the order of 0.1\xa0K based on extensive comparisons, there is a remaining issue that persisted over the years. A calibration bias on the order of 0.1\xa0K is introduced in channels such as M15 during the quarterly blackbody temperature warm‐up/cooldown, and the bias is further amplified by the sea surface temperature (SST) retrieval algorithm up to 0.3\xa0K in the global daily‐averaged products which causes an apparent spike in the SST time series. Our investigation reveals that this bias is caused by a fundamental but flawed theoretical assumption in the VIIRS calibration equation, which states that the shape of the calibration curve is assumed unchanged from prelaunch to postlaunch without any constrains. While the assumption may work to account for long‐term degradation, it has a shortcoming during the blackbody unsteady state. In this study, we present a diagnostic and correction method with a compensatory term (Ltrace) to reconcile the assumption such that it removes the calibration bias during the blackbody temperature changes. The methodology has been tested using historical data, and the results are very positive. The implementation has minimal impacts on the operational data processing system and is readily available for use in operations.\n\nKey Points \n\n\nSuomi NPP VIIRS long‐wave infrared bands have been working well, except for a\xa0~\xa00.1\xa0K bias found during blackbody unsteady states \nOur analysis shows that this anomaly is traced to a key assumption of calibration curve shape in the algorithm theoretical basis \nA diagnostic method and correction algorithm is developed and tested to resolve this bias\n\n',
#      'title': 'Radiometric traceability diagnosis and bias correction for the Suomi NPP VIIRS long‐wave infrared channels during blackbody unsteady states',
#      'isOpenAccess': False,
#      'publicationDate': '15 May 2017',
#      'journalTitle': 'Journal of Geophysical Research: Atmospheres'},
#     'total_chunks': 19}},
#   {'id': '10.1120/jacmp.v16i2.4917_0003',
#    'version': None,
#    'score': None,
#    'reranking_score': 0.48341134190559387,
#    'collection_name': 'Wiley AI Gateway',
#    'payload': {},
#    'text': "## II. MATERIALS AND METHODS\n\nThe software is able to trigger on different events such as inspirationpeak, expirationpeak or derived events, so that the system can be classified as a phasebased triggering system ([Fig. 1(a)](#acm20334-fig-0001)).\n\nThe Sentinel system consists of a laser which sweeps within a few seconds over the surface of the patient and a camera to detect the laser projections ([Fig. 3(a)](#acm20334-fig-0003)). From multiple projection lines, the software generates a static threedimensional model of the patient's surface. In addition to assistance in patient positioning, the Sentinel system contains a software module for 4D CT acquisition (c4D Version 4.5.0). By spotting a userdefined region on the surface of a patient ([Fig. 3(b)](#acm20334-fig-0003)) and subsequent triangulation, an online surrogate signal of the patient's respiration can be acquired, which bases on the anterior/posterior movement (Z position) of the selected region. The resulting respiratory signal is scaled absolute and displayed in millimeters. By the use of two threshold values for the respiratory signal a window can be specified. Trigger events are released either on entrance or exit of the specified window or a combination of both. Since triggers are released at defined threshold values, the Sentinel system is an amplitudebased triggering system (compare [Fig. 1(b)](#acm20334-fig-0001)\n\n**Figure Context:**\n**1**\n*Scheme of the cyclebased 4D CT mode as it is implemented in the Toshiba scanner. An exemplary respiratory signal with corresponding triggers delivered by (a) the Anzai System and (b) the Sentinel system is used to reconstruct  respiratory phases. Triggers are expected to indicate the beginning o...*\n\n{#acm20334-fig-0001}\n). The c4D software does not provide any option to trigger on inspiration or expiration peaks.\n\nThere are at least two problems that have to be addressed to assure the accuracy of the recorded respiratory signal. First, the laser has to track the userspecified measurement region correctly during couch movements. Therefore, the Sentinel system requires a wire ruler ([Fig. 3(c)](#acm20334-fig-0003)) that delivers the couch position to the laser positioning controller. Second, a CT couch typically consists of carbon fibers and is mounted with a slight pretension in positive Z direction to compensate for defections under the load of a patient. Depending on the patient's weight and the actual couch position, different defections in Z direction can be observed, which are superimposed on the respiratory signal. In order to correct this error, the Sentinel system makes use of a couch calibration profile. During the calibration process two profiles are recorded. The first one is used for daily check purposes only and, despite the Sentinel's QA Phantom, no additional weights are placed on the CT couch. The second couch calibration profile is recorded with the Sentinel's QA Check Phantom and additional calibration weights of 80 kg. The weights are placed along the couch to reproduce a typical patient load. This profile is used in the clinical mode for all patients regardless of their actual weight. The calibration weight of 70 kg recommended in the Sentinel's manual is increased by 10 kg to reproduce a representative patient weight in our clinic.\n\n**3**\n\n*Installation and application of the Sentinel system: (a) Sentinel unit mounted at the ceiling; (b) patient setup and coordinate system; (c) the wire ruler (red) measures the couch position in Y direction and is mounted at the foot of the CT couch.*\n{#acm20334-fig-0003}",
#    'metadata': {'journal_code': '15269914',
#     'article_type': 'article',
#     'pub_type': 'article',
#     'journal_issn': '1526-9914',
#     'additionalMetadata': {'volume': '16',
#      'pageRange': '334-349',
#      'citationLine': 'Heinz, C., Reiner, M., Belka, C., Walter, F., & Söhn, M. (2015). Technical evaluation of different respiratory monitoring systems used for 4D CT acquisition under free breathing. Journal of Applied Clinical Medical Physics, 16(2), 334-349. https://doi.org/10.1120/jacmp.v16i2.4917',
#      'issue': '2',
#      'link': 'https://doi.org/10.1120/jacmp.v16i2.4917',
#      'isRetracted': False,
#      'publisher': 'John Wiley & Sons, Ltd',
#      'abstract': "Respiratory monitoring systems are required to supply CT scanners with information on the patient's breathing during the acquisition of a respiration‐correlated computer tomography (RCCT), also referred to as 4D CT. The information a respiratory monitoring system has to provide to the CT scanner depends on the specific scanner. The purpose of this study is to compare two different respiratory monitoring systems (Anzai Respiratory Gating System; C‐RAD Sentinel) with respect to their applicability in combination with an Aquilion Large Bore CT scanner from Toshiba. The scanner used in our clinic does not make use of the full time dependent breathing signal, but only single trigger pulses indicating the beginning of a new breathing cycle. Hence the attached respiratory monitoring system is expected to deliver accurate online trigger pulse for each breathing cycle. The accuracy of the trigger pulses sent to the CT scanner has to be ensured by the selected respiratory monitoring system. Since a trigger pulse (output signal) of a respiratory monitoring system is a function of the measured breathing signal (input signal), the typical clinical range of the input signal is estimated for both examined respiratory monitoring systems. Both systems are analyzed based on the following parameters: time resolution, signal amplitude, noise, signal‐to‐noise ratio (SNR), signal linearity, trigger compatibility, and clinical examples. The Anzai system shows a better SNR ( ) than the Sentinel system ( ). In terms of compatibility with the cycle‐based image sorting algorithm of the Toshiba CT scanner, the Anzai system benefits from the possibility to generate cycle‐based triggers, whereas the Sentinel system is only able to generate amplitude‐based triggers. In clinical practice, the combination of a Toshiba CT scanner and the Anzai system will provide better results due to the compatibility of the image sorting and trigger release methods. \nPACS numbers: 87.57.Q‐, 07.07.Df\n\n",
#      'title': 'Technical evaluation of different respiratory monitoring systems used for 4D CT acquisition under free breathing',
#      'isOpenAccess': True,
#      'publicationDate': '08 March 2015',
#      'journalTitle': 'Journal of Applied Clinical Medical Physics'},
#     'total_chunks': 15}},
#   {'id': '10.1002/hbm.20040_0015',
#    'version': None,
#    'score': None,
#    'reranking_score': 0.14300739765167236,
#    'collection_name': 'Wiley AI Gateway',
#    'payload': {},
#    'text': '## Acknowledgements\n\nWe thank R. Brans, I. Carati, X. Chitnis, M. Langen, and T. van Raalten for their assistance in the calibration study.',
#    'metadata': {'journal_code': '10970193',
#     'article_type': 'article',
#     'pub_type': 'article',
#     'journal_issn': '1097-0193',
#     'additionalMetadata': {'volume': '22',
#      'pageRange': '312-320',
#      'citationLine': 'Schnack, H. G., van Haren, N. E., Hulshoff Pol, H. E., Picchioni, M., Weisbrod, M., Sauer, H., Cannon, T., Huttunen, M., Murray, R., & Kahn, R. S. (2004). Reliability of brain volumes from multicenter MRI acquisition: A calibration study. Human Brain Mapping, 22(4), 312-320. https://doi.org/10.1002/hbm.20040',
#      'issue': '4',
#      'link': 'https://doi.org/10.1002/hbm.20040',
#      'isRetracted': False,
#      'publisher': 'John Wiley & Sons, Ltd',
#      'abstract': 'Abstract \n\nMulticenter studies can provide additional information over single center studies because of their increased statistical power. Because similar acquisition protocols are being used internationally for structural magnetic resonance imaging (MRI) studies of the human brain, volumetric MRI data studies seem suitable for this purpose. Possible systematic differences between sites should be avoided, however, particularly when subtle differences in tissue volume are being searched for, such as in neuropsychiatric diseases. In this calibration study, the brains of six healthy volunteers were (re)scanned with MR scanners from four different manufacturers at five different sites, using the local acquisition protocols. The images were segmented at a central reference site. The intraclass correlation coefficient (ICC) was determined for the whole brain, gray and white matter, cerebellum, and lateral and third ventricle volumes. When required, the processing algorithms were calibrated for each site. Calibration of the histogram analysis was needed for segmentation of total brain volume at one site and for gray and white matter volume at all sites. No (additional) calibration was needed for cerebellum and ventricle volumes. The ICCs were ≥0.96 for total brain, ≥0.92 for cerebellum, ≥0.96 for lateral ventricle, ≥0.21 for third ventricle, ≥0.84 for gray matter, and ≥0.78 for white matter volume. Calibration of segmentation procedures allows morphologic MRI data acquired at different research sites to be combined reliably in multicenter studies. Hum. Brain Mapping 22:312–320, 2004. © 2004 Wiley‐Liss, Inc.\n\n',
#      'title': 'Reliability of brain volumes from multicenter MRI acquisition: A calibration study',
#      'isOpenAccess': False,
#      'publicationDate': '03 June 2004',
#      'journalTitle': 'Human Brain Mapping'},
#     'total_chunks': 16}},
#   {'id': '10.1155/2020/5060969_0006',
#    'version': None,
#    'score': None,
#    'reranking_score': 0.7792726159095764,
#    'collection_name': 'Wiley AI Gateway',
#    'payload': {},
#    'text': '## 4. Result Analysis and Discussion\n\nSentinel 2 satellite imageries were selected to evaluate their suitability for investigating water quality in inland water. Sentinel 2 images were obtained from the European Space Agency through Copernicus Open Access Hub ([https://scihub.copernicus.eu](https://scihub.copernicus.eu/)). Three images of level1C (L1C) MSI data were used in this study. Table [4](#tbl-0004) summarizes Sentinel 2 images used for algorithm development.\n\n**Table 4**\n\n| Location | Identifier | Acquisition date | Cloud cover |\n| --- |\n| KTD | S2B_MSIL1C_20190715T081609_N0208_R121_T36SYA_20190715T120216 | 20190715 | 1.4111 |\n| Mujib | S2A_MSIL1C_20190630T081611_N0207_R121_T36RYV_20190630T102130 | 20190630 | 1.3674 |\n| Wadi AlArab | S2B_MSIL1C_20190625T081609_N0207_R121_T36SYB_20190625T120443 | 20190625 | 0.0018 |\n{#tbl-0004}\n\nThe L1C data are obtained as digital numbers that represent topofatmosphere (TOA) reflectance with 10, 20, and 60m bands resolution (Table [5](#tbl-0005)). The images bands were resampled to 20m resolution using Sentinel Application Platform (SNAP) version 6.0.\n\n**Table 5**\n\n| Band (spatial resolution) | Band range (nm) | Central wavelength (nm) |\n| --- |\n| Band 1 coastal/aerosol (60m) | 421457 | 443 |\n| Band 2 blue (10m) | 439535 | 490 |\n| Band 3 green (10m) | 537582 | 560 |\n| Band 4 red (10m) | 646685 | 665 |\n| Band 5 VRE (20m) | 694714 | 705 |\n| Band 6 VRE (20m) | 731749 | 740 |\n| Band 7 VRE (20m) | 768796 | 783 |\n| Band 8 NIR (10m) | 767908 | 842 |\n| Band 8a NIR (20m) | 858881 | 865 |\n| Band 9 WV (60m) | 931958 | 945 |\n| Band 10 cirrus (60m) | 13381414 | 1375 |\n| Band 11 SWIR (20m) | 15391681 | 1610 |\n| Band 12 SWIR (20m) | 20722312 | 2190 |\n{#tbl-0005}\n\nSince TOA reflectance is significantly affected by atmospheric conditions that may lead to a considerable uncertainty in the satellite data, an atmospheric correction protocol is necessary for an accurate estimation of the surface reflectance (SR) of a ground target. Atmospheric and topographic correction (ATCOR) is the most common physical methods to convert the topofatmosphere (TOA) to remote sensing reflectance (R~rs~) [[38](#bib-0038)]. PCI Geomatica (2017) (ATCOR based) software was used to perform atmospheric correction to eliminate terrain and atmospheric effects.\n\nIn this study, georeferenced Chla concentration from the three dams (King Talal Dam, Mujib Dam, and Wadi AlArab Dam) and corresponding Sentinel 2 satellite pixels were used to develop a Chla predictive model. In total, 58 water samples were collected and considered for investigation. The collected data were divided into two sets. the first set contains 39 points and was used for calibration. The second set contains 19 points and was used for validation. The Chla algorithms found in the literature adopted to Sentinel 2 spectral band configuration use ratios and combinations of two bands.\n\nFigures [8](#fig-0008)[10](#fig-0010) present the performance of different algorithms that correlate band widths combinations with Chla measured concentration. Model calibration results using 2band models showed a very strong relationship with Chla than using an exponential function. The bestfitted models showed the highest *R*^2^ of 0.907.\n\n**Figure 8**\n\n*Regression between the Sentinel 2 band index and measured Chla, using the B2/B3 model.*\n{#fig-0008}\n\n**Figure 9**\n\n*Regression between the Sentinel 2 band index and measured Chla, using the B3/B2 model.*\n{#fig-0009}\n\n**Figure 10**\n\n*Regression between the Sentinel 2 band index and measured Chla, using the Ln(B2/B3) model.*\n{#fig-0010}\n\n**Figure Context:**\n**Figure 1**\n*Jordans map with selected dams locations.*\n\n{#fig-0001}',
#    'metadata': {'journal_code': '8086',
#     'article_type': 'researchArticle',
#     'pub_type': 'article',
#     'journal_issn': '1537-744X',
#     'additionalMetadata': {'volume': '2020',
#      'citationLine': 'Hussein, N. M., Assaf, M. N., & Smith, R. A. (2020). Multispectral Remote Sensing Utilization for Monitoring Chlorophyll‐a Levels in Inland Water Bodies in Jordan. The Scientific World Journal, 2020(1). https://doi.org/10.1155/2020/5060969',
#      'issue': '1',
#      'link': 'https://doi.org/10.1155/2020/5060969',
#      'isRetracted': False,
#      'publisher': 'John Wiley & Sons, Ltd',
#      'abstract': 'This study focuses on the utilization of multispectral satellite images for remote water‐quality evaluation of inland water body in Jordan. The geophysical parameters based on water’s optical properties, due to the presence of optically active constituents, are used to determine contaminant level in water. It has a great potential to be employed for continuous and cost‐effective water‐quality monitoring and leads to a reliable regularly updated tool for better water sector management. Three sets of water samples were collected from three different dams in Jordan. Chl‐a concentration of the water samples was measured and used with corresponding Sentinel 2 surface reflectance (SR) data to develop a predictive model. Chl‐a concentrations and corresponding SR data were used to calibrate and validate different models. The predictive capability of each of the investigated models was determined in terms of determination coefficient (R2) and lowest root mean square error (RMSE) values. For the investigated sites, the B3/B2 (green/blue bands) model and the Ln (B3/B2) model showed the best overall predictive capability of all models with the highest R2 and the lowest RMSE values of (0.859, 0.824) and (30.756\u2009mg/m3, 29.787\u2009mg/m3), respectively. The outcome of this study on selected sites can be expanded for future work to cover more sites in the future and ultimately cover all sites in Jordan.\n\n',
#      'title': 'Multispectral Remote Sensing Utilization for Monitoring Chlorophyll‐a Levels in Inland Water Bodies in Jordan',
#      'isOpenAccess': True,
#      'publicationDate': '07 August 2020',
#      'journalTitle': 'The Scientific World Journal'},
#     'total_chunks': 9}}],
#  'latencies': {'reranking_latency': 1.251646921999054,
#   'query_embedding_latency': 0.6761371929896995,
#   'qdrant_retrieval_latency': 0.10942486100248061,
#   'mcp_retrieval_latency': 1.7607605429948308,
#   'rewrite': 1.4853388479968999},
#  'original_query': 'How to calibrate Sentinel-2?',
#  'requery': 'Sentinel-2 calibration'}

# %% [markdown]
# ### 2. `POST /conversations/{conversation_id}/messages` — RAG Generation
#
# Creates a new message in a conversation and generates a grounded answer using the full **Retrieval-Augmented Generation (RAG)** pipeline. The API retrieves the most relevant documents from the specified collections, injects them as context, and passes everything — including the conversation history — to the LLM.
#
# **When to use it**
# - The primary endpoint for interacting with EVE in a multi-turn dialogue.
# - Any time you need grounded, citation-backed answers from the knowledge base.
# - Comparing retrieval quality across different `k`, `score_threshold`, or `embeddings_model` settings.
#
# > **Retrieval + LLM = grounded answers with source documents.**
# > The response includes the generated `answer`, the list of retrieved `documents` (with scores), and a `use_rag` flag confirming that retrieval ran. The conversation history is automatically threaded through `conversation_id`.
#
# **Path parameter**
#
# | Parameter | Type | Required | Description |
# |---|---|---|---|
# | `conversation_id` | string | Yes | ID of the conversation thread (create one with `POST /conversations`) |
#
# **Request body (`GenerationRequest`)**
#
# | Field | Type | Default | Description |
# |---|---|---|---|
# | `query` | string | `"What is ESA?"` | User prompt sent through the RAG pipeline |
# | `public_collections` | string[] | `[]` | Named document collections to search (e.g. `"qwen-512-filtered"`) |
# | `k` | integer (0–10) | `3` | Number of documents to retrieve |
# | `score_threshold` | float (0–1) | `0.7` | Minimum cosine similarity score for a document to be included |
# | `embeddings_model` | string | `"Qwen/Qwen3-Embedding-4B"` | Embedding model used for retrieval |
# | `llm_type` | string \| null | `null` | LLM variant: `"main"`, `"fallback"`, `"eve_v05"`, `"satcom_small"`, etc. |
# | `temperature` | float (0–1) | `0.0` | Sampling temperature for the LLM |
# | `max_new_tokens` | integer | `100000` | Maximum tokens the LLM may generate |
# | `year` | integer[] \| null | `null` | Optional filter: restrict retrieval to documents from these years |
# | `filters` | object \| null | `null` | Additional metadata filters for the vector store query |
#
# **Response (`CreateMessageResponse`)**
#
# | Field | Type | Description |
# |---|---|---|
# | `id` | string | Message ID |
# | `query` | string | The original user query |
# | `answer` | string | LLM-generated, grounded answer |
# | `documents` | DocumentReference[] | Retrieved source documents with scores |
# | `use_rag` | boolean | `true` when retrieval ran |
# | `conversation_id` | string | The conversation this message belongs to |
# | `metadata` | ResponseMetadata | Latency and model metadata |

# %%
def create_conversation(base_url: str, token: str, name: str = "RAG demo") -> str:
    """Create a new conversation thread and return its ID."""
    resp = requests.post(
        f"{base_url}/conversations",
        json={"name": name},
        headers={"Authorization": f"Bearer {token}"},
        timeout=15,
    )
    resp.raise_for_status()
    conv_id = resp.json()["id"]
    print(f"Conversation created: {conv_id}")
    return conv_id


def create_message(
    base_url: str,
    token: str,
    conv_id: str,
    query: str,
    public_collections: list[str] | None = None,
    k: int = 3,
    score_threshold: float = 0.5,
    llm_type: str | None = None,
    temperature: float = 0.0,
) -> dict:
    """Send a query through the full RAG pipeline and return the response."""
    payload = {
        "query": query,
        "public_collections": public_collections or ["EVE open access"],
        "k": k,
        "score_threshold": score_threshold,
        "temperature": temperature,
    }
    if llm_type:
        payload["llm_type"] = llm_type

    resp = requests.post(
        f"{base_url}/conversations/{conv_id}/messages",
        json=payload,
        headers={"Authorization": f"Bearer {token}"},
        timeout=120,
    )
    resp.raise_for_status()
    return resp.json()


def display_rag_response(result: dict, query: str = ""):
    """Pretty-print the RAG generation response including retrieved documents."""
    sep = "─" * 72
    answer = result.get("answer") or result.get("text") or str(result)
    documents = result.get("documents", [])
    use_rag = result.get("use_rag", False)
    metadata = result.get("metadata", {})
    latencies = (metadata.get("latencies") or {}) if metadata else {}

    if query:
        print(f"❓ Query         : {query}")
        print()

    # Answer
    print(sep)
    print(f"🔍 RAG enabled   : {use_rag}  |  Documents retrieved: {len(documents)}")
    print(sep)
    print("🤖 Answer")
    print(sep)
    print(answer)
    print()

    # Retrieved documents — same detail level as /retrieve
    if documents:
        print(sep)
        print(f"📄  {len(documents)} document(s) retrieved")
        print(sep)
        for i, doc in enumerate(documents, 1):
            score           = doc.get("score")
            reranking_score = doc.get("reranking_score")
            collection      = doc.get("collection_name", "N/A")
            text            = doc.get("text", "")
            payload         = doc.get("payload", {})

            print(sep)
            print(f"  Document {i}  |  Collection: {collection}")
            print(sep)

            if score is not None:
                bar = "█" * int(score * 20)
                print(f"  score           {score:.4f}  [{bar:<20}]")
                print(f"                  ↳ cosine similarity query↔doc embedding (≥ score_threshold kept)")
            if reranking_score is not None:
                print(f"  reranking_score {reranking_score:.4f}")
                print(f"                  ↳ cross-encoder score; final ranking signal — higher = more relevant")

            snippet = text[:400].replace("\n", " ") + ("…" if len(text) > 400 else "")
            print(f"  text snippet    {snippet}")

            if payload:
                print("  metadata:")
                for k, v in payload.items():
                    print(f"    {k}: {v}")
            print()

    # Latency breakdown
    if latencies:
        print(sep)
        print("⏱  Pipeline Latencies")
        for stage, secs in latencies.items():
            if secs is not None:
                print(f"   {stage:<30} {secs:.3f} s")
            else:
                print(f"   {stage:<30} —")
        print()


conv_id = create_conversation(BASE_URL, access_token)
query = "What is Sentinel Satellite?"
rag_result = create_message(BASE_URL, access_token, conv_id, query)
display_rag_response(rag_result, query=query)
# Out:
# Conversation created: 6a059858fa29b9191e606eea
# ❓ Query         : What is Sentinel Satellite?
#
# ────────────────────────────────────────────────────────────────────────
# 🔍 RAG enabled   : True  |  Documents retrieved: 0
# ────────────────────────────────────────────────────────────────────────
# 🤖 Answer
# ────────────────────────────────────────────────────────────────────────
# The Sentinel satellites are a series of Earth Observation satellites developed by the European Space Agency (ESA) as part of the **Copernicus Programme**. They are designed to provide high-quality, continuous, and reliable data for environmental monitoring, climate change studies, and disaster management. Here’s a structured overview:
#
# ---
#
# ### **Key Aspects of Sentinel Satellites**
# 1. **Purpose**:
#    - Monitor Earth’s environment, climate, and security.
#    - Support policy-making, disaster response, and scientific research.
#    - Provide data for applications like land management, ocean monitoring, and atmospheric studies.
#
# 2. **Operated by**:
#    - **European Space Agency (ESA)** in collaboration with the **European Commission**.
#    - Part of the **Copernicus Programme**, Europe’s flagship Earth Observation initiative.
#
# 3. **Satellite Families**:
#    The Sentinel fleet consists of multiple satellite families, each specialized for specific observations:
#    - **Sentinel-1**: Radar imaging for land and ocean monitoring (e.g., disaster response, sea ice tracking).
#    - **Sentinel-2**: Optical imaging for land cover, vegetation, and emergency response (e.g., agriculture, forestry).
#    - **Sentinel-3**: Ocean and land surface temperature, color, and topography (e.g., marine ecosystems, wildfires).
#    - **Sentinel-5P**: Atmospheric composition monitoring (e.g., air quality, pollution tracking).
#    - **Sentinel-6**: Sea level monitoring (e.g., climate change studies).
#
# 4. **Technical Features**:
#    - **High-resolution sensors**: Capture detailed imagery and measurements.
#    - **Global coverage**: Designed for systematic and frequent observations.
#    - **Open data policy**: Data is freely accessible to users worldwide.
#
# 5. **Applications**:
#    - **Environmental Monitoring**: Track deforestation, glacier retreat, and urban expansion.
#    - **Disaster Management**: Support flood, earthquake, and wildfire response efforts.
#    - **Climate Change**: Measure sea level rise, ice melt, and atmospheric changes.
#    - **Agriculture**: Monitor crop health and optimize farming practices.
#    - **Oceanography**: Study marine ecosystems, currents, and pollution.
#
# 6. **Why Are They Important?**
#    - Provide **consistent, long-term data** for scientific research and policy decisions.
#    - Enable **real-time monitoring** for timely disaster response.
#    - Support **sustainable development** by tracking environmental changes.
#    - Foster **global collaboration** through open data access.
#
# ---
#
# ### **Example Use Cases**
# - **Sentinel-1**: Used to map flood extents during natural disasters.
# - **Sentinel-2**: Tracks changes in crop health for precision agriculture.
# - **Sentinel-3**: Monitors ocean temperatures to study climate patterns.
# - **Sentinel-5P**: Measures air pollution levels in urban areas.
# - **Sentinel-6**: Tracks global sea level rise to assess climate impacts.
#
# ---
#
# ### **Data Access**
# - All Sentinel data is freely available through the **Copernicus Open Access Hub** and other platforms.
# - Researchers, students, and policymakers can use this data for analysis, modeling, and decision-making.
#
# For more details, you can explore resources from ESA or the Copernicus Programme.
#
# ────────────────────────────────────────────────────────────────────────
# ⏱  Pipeline Latencies
#    guardrail_latency              —
#    rag_decision_latency           1.213 s
#    query_embedding_latency        —
#    qdrant_retrieval_latency       —
#    mcp_retrieval_latency          —
#    reranking_latency              —
#    base_generation_latency        22.275 s
#    fallback_latency               —
#    hallucination_latency          —
#    total_latency                  23.503 s

# %%
rag_result
# Out:
# {'id': '6a059858fa29b9191e606eeb',
#  'query': 'Sentinel Satellite definition',
#  'answer': 'The Sentinel satellites are a series of Earth Observation satellites developed by the European Space Agency (ESA) as part of the **Copernicus Programme**. They are designed to provide high-quality, continuous, and reliable data for environmental monitoring, climate change studies, and disaster management. Here’s a structured overview:\n\n---\n\n### **Key Aspects of Sentinel Satellites**\n1. **Purpose**:\n   - Monitor Earth’s environment, climate, and security.\n   - Support policy-making, disaster response, and scientific research.\n   - Provide data for applications like land management, ocean monitoring, and atmospheric studies.\n\n2. **Operated by**:\n   - **European Space Agency (ESA)** in collaboration with the **European Commission**.\n   - Part of the **Copernicus Programme**, Europe’s flagship Earth Observation initiative.\n\n3. **Satellite Families**:\n   The Sentinel fleet consists of multiple satellite families, each specialized for specific observations:\n   - **Sentinel-1**: Radar imaging for land and ocean monitoring (e.g., disaster response, sea ice tracking).\n   - **Sentinel-2**: Optical imaging for land cover, vegetation, and emergency response (e.g., agriculture, forestry).\n   - **Sentinel-3**: Ocean and land surface temperature, color, and topography (e.g., marine ecosystems, wildfires).\n   - **Sentinel-5P**: Atmospheric composition monitoring (e.g., air quality, pollution tracking).\n   - **Sentinel-6**: Sea level monitoring (e.g., climate change studies).\n\n4. **Technical Features**:\n   - **High-resolution sensors**: Capture detailed imagery and measurements.\n   - **Global coverage**: Designed for systematic and frequent observations.\n   - **Open data policy**: Data is freely accessible to users worldwide.\n\n5. **Applications**:\n   - **Environmental Monitoring**: Track deforestation, glacier retreat, and urban expansion.\n   - **Disaster Management**: Support flood, earthquake, and wildfire response efforts.\n   - **Climate Change**: Measure sea level rise, ice melt, and atmospheric changes.\n   - **Agriculture**: Monitor crop health and optimize farming practices.\n   - **Oceanography**: Study marine ecosystems, currents, and pollution.\n\n6. **Why Are They Important?**\n   - Provide **consistent, long-term data** for scientific research and policy decisions.\n   - Enable **real-time monitoring** for timely disaster response.\n   - Support **sustainable development** by tracking environmental changes.\n   - Foster **global collaboration** through open data access.\n\n---\n\n### **Example Use Cases**\n- **Sentinel-1**: Used to map flood extents during natural disasters.\n- **Sentinel-2**: Tracks changes in crop health for precision agriculture.\n- **Sentinel-3**: Monitors ocean temperatures to study climate patterns.\n- **Sentinel-5P**: Measures air pollution levels in urban areas.\n- **Sentinel-6**: Tracks global sea level rise to assess climate impacts.\n\n---\n\n### **Data Access**\n- All Sentinel data is freely available through the **Copernicus Open Access Hub** and other platforms.\n- Researchers, students, and policymakers can use this data for analysis, modeling, and decision-making.\n\nFor more details, you can explore resources from ESA or the Copernicus Programme.',
#  'documents': [],
#  'use_rag': True,
#  'conversation_id': '6a059858fa29b9191e606eea',
#  'loop_result': None,
#  'trace': None,
#  'metadata': {'latencies': {'guardrail_latency': None,
#    'rag_decision_latency': 1.2130988869757857,
#    'query_embedding_latency': None,
#    'qdrant_retrieval_latency': None,
#    'mcp_retrieval_latency': None,
#    'reranking_latency': None,
#    'base_generation_latency': 22.275081894011237,
#    'fallback_latency': None,
#    'hallucination_latency': None,
#    'total_latency': 23.503398573986487}}}

# %% [markdown]
# You can also explore the live interactive docs at `https://staging-agentic-api.eve-chat.chat/docs`.

# %% [markdown]
# ## Agentic Capabilities *(Experimental)*
#
# Beyond the standard endpoints above, EVE exposes an **experimental agentic layer** that connects the model to the tools we built in the previous sections. The agent can autonomously plan which tools to call, execute them, observe their results, and loop until it has gathered enough context to answer the query — all in a single API call.
#
# > These endpoints are still under **active development**; interfaces and behaviour may change between releases.
#
# ### The ReAct Loop
#
# The agent architecture used here is called [ReAct (Reason + Act) (Yao et al., 2023)](https://arxiv.org/abs/2210.03629). The model alternates between two modes:
#
# - **Reasoning** — the model thinks through what it knows and what it still needs.
# - **Acting** — the model emits a structured tool call that the host application executes.
#
# <img src="https://eve-nasa-earthrise-book-assets.s3.us-east-1.amazonaws.com/diagrams/react_loop_flow.svg" alt="The ReAct loop: the LLM reasons, calls a tool, observes the result, and repeats until a final response is ready" style="max-width: 700px;" />
#
# *Fig. 2. The ReAct loop: the LLM reasons, calls a tool, observes the result, and repeats until a final response is ready.*
#
# LangGraph implements this as a graph with exactly **two nodes** — an LLM node and a tools node — connected in a loop that terminates when the LLM produces a response with no further tool calls.
#
# <img src="images/langgraph_diagram.png" alt="EVE's LangGraph implementation" style="max-width: 700px;" />
#
# ### Agentic Endpoints
#
# | Endpoint | Description |
# |---|---|
# | `POST /conversations/{conversation_id}/generate-agentic` | Synchronous: the agent loops until it produces a final answer. Returns the full response including an execution `trace`. |
# | `POST /conversations/{conversation_id}/stream-generate-agentic` | Streaming variant via Server-Sent Events (SSE). Emits `tool_call`, `tool_result`, `token`, `final`, `stopped`, and `error` events. |
#
# ### Building a Request
#
# In addition to the standard LLM parameters (`temperature`, `max_new_tokens`), agentic requests require specifying which MCP servers to involve via the `public_mcp_servers` parameter.
#
# > **Why the `public` prefix?**
# > These are servers available to all users. A future release will support private per-user MCP servers.

# %% [markdown]
# ### Login
#
# As done in the previous section, we login to the system getting an access token

# %%
import argparse
import json
import sys
import time
from typing import List
import requests


def login(base_url: str, email: str, password: str) -> str:
    print(f"Logging in with email: {email} and password: ***")
    resp = requests.post(
        f"{base_url}/login",
        json={"email": email, "password": password},
        timeout=30,
    )
    if resp.status_code != 200:
        print(f"Login failed ({resp.status_code}): {resp.text}")
    print(resp.json())
    token = resp.json()["access_token"]
    return token

def build_payload(query: str,  public_mcp_servers: List[str]) -> dict:
    return {
        "query": query,
        "temperature": 0.1,
        "max_new_tokens": 8192,
        "public_mcp_servers": public_mcp_servers,
    }

access_token = login(BASE_URL, EMAIL, PASSWORD)
public_mcp_servers = ["geocode"]
# Out:
# Logging in with email: pischool@eve.com and password: ***
# {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE3Nzg3NTI1MDAsInN1YiI6IjY5ZjhhMTYxODIwMjYzMTI4YTllZjZhOSIsImF1ZCI6ImFjY2VzcyJ9.2LW-Md9nMJxlZSMgc8r_OaFRjGrlWzYtIojuPE8eb5c', 'refresh_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE3NzkzNTY0MDAsInN1YiI6IjY5ZjhhMTYxODIwMjYzMTI4YTllZjZhOSIsImp0aSI6IjdiOTYzZjM0LWNjZjEtNDEwOC05YWJhLWNiNDM1MGRhMzA2ZSIsImF1ZCI6InJlZnJlc2gifQ.hlBklpmm_Hn9_xQnhKQ5O_qNse60-D8ik99IXJmrE_k'}

# %% [markdown]
# ### Calling the Agentic Endpoint
#
# Let's implement the agentic call and test it end-to-end.

# %%
from requests.exceptions import ChunkedEncodingError, ConnectionError as RequestsConnectionError
from urllib3.exceptions import ProtocolError as Urllib3ProtocolError
import requests


GREEN = "\033[92m"
RED = "\033[91m"
YELLOW = "\033[93m"
CYAN = "\033[96m"
BOLD = "\033[1m"
RESET = "\033[0m"

def generate_agentic(
    payload, base_url: str, token: str, conv_id: str
) -> dict | None:
    """Same GenerationRequest as streaming; uses POST /generate-agentic (JSON body, no SSE)."""
    resp = requests.post(
        f"{base_url}/conversations/{conv_id}/generate-agentic",
        json=payload,
        headers={"Authorization": f"Bearer {token}"},
        timeout=600,
    )
    if resp.status_code != 200:
        print(f"Blocking agentic failed ({resp.status_code}): {resp.text[:800]}")
        return None
    data = resp.json()
    return data


def stream_generate_agentic(
    payload,
    base_url: str,
    token: str,
    conv_id: str,
    max_stream_retries: int = 4,
):

    stream_timeout = (30, 600)  # (connect, read between chunks) seconds

    for attempt in range(max_stream_retries):
        t0 = time.perf_counter()
        token_count = 0
        tool_calls = []
        final_payload = None
        answer_chars = 0
        first_token_latency = None

        try:
            with requests.post(
                f"{base_url}/conversations/{conv_id}/stream-generate-agentic",
                json=payload,
                headers={
                    "Authorization": f"Bearer {token}",
                    "Accept": "text/event-stream",
                    "Connection": "keep-alive",
                },
                stream=True,
                timeout=stream_timeout,
            ) as resp:
                if resp.status_code != 200:
                    print(f"Stream endpoint failed ({resp.status_code}): {resp.text[:500]}")
                    return None

                print()
                for raw_line in resp.iter_lines(chunk_size=16384):
                    if not raw_line:
                        continue
                    line = (
                        raw_line.decode("utf-8")
                        if isinstance(raw_line, bytes)
                        else raw_line
                    )
                    if not line.startswith("data: "):
                        continue
                    payload_str = line[len("data: ") :]

                    # Parse JSON events
                    try:
                        event = json.loads(payload_str)
                    except json.JSONDecodeError:
                        # Plain-text token (non-JSON stream mode)
                        token_count += 1
                        if first_token_latency is None:
                            first_token_latency = time.perf_counter() - t0
                        print(payload_str, end="", flush=True)
                        answer_chars += len(payload_str)
                        continue

                    etype = event.get("type")

                    if etype == "tool_call":
                        tool_calls.append(event.get("content", ""))
                        print(
                            f"\n{YELLOW}  🔍 {event.get('content', '')}{RESET}", flush=True
                        )

                    elif etype == "tool_result":
                        preview = event.get("content", "")[:80]
                        print(f"\n{CYAN}  ↩  result preview: {preview}…{RESET}", flush=True)

                    elif etype == "token":
                        content = event.get("content", "")
                        if first_token_latency is None:
                            first_token_latency = time.perf_counter() - t0
                        token_count += 1
                        answer_chars += len(content)
                        print(content, end="", flush=True)

                    elif etype == "final":
                        final_payload = event
                        print()  # newline after streamed tokens

                    elif etype == "stopped":
                        print("Generation was stopped by the server")
                        break

                    elif etype == "error":
                        print(f"Stream error: {event.get('message')}")

        except requests.exceptions.Timeout:
            print("Request timed out (connect or idle-between-chunks limit).")
            if attempt < max_stream_retries - 1:
                wait = 2**attempt
                print(f"{YELLOW}Retrying in {wait}s ({attempt + 2}/{max_stream_retries})…{RESET}")
                time.sleep(wait)
                continue
            print(f"\n{RED}Stream timed out after {max_stream_retries} attempts.{RESET}")
            return None

        except (ChunkedEncodingError, Urllib3ProtocolError, RequestsConnectionError) as e:
            if attempt < max_stream_retries - 1:
                wait = 2**attempt
                print(
                    f"\n{YELLOW}Stream dropped ({type(e).__name__}: {e}). "
                    f"Retrying in {wait}s ({attempt + 2}/{max_stream_retries})…{RESET}",
                    flush=True,
                )
                time.sleep(wait)
                continue
            print(f"\n{RED}Stream failed after {max_stream_retries} attempts: {e}{RESET}")
            return None

        elapsed = time.perf_counter() - t0
        print()
        print(f"Stream completed in {elapsed:.2f}s")
        print(
            f"First-token latency  : {first_token_latency:.2f}s"
            if first_token_latency
            else "First-token latency: n/a"
        )
        print(f"Tokens/events yielded: {token_count}")
        print(f"Answer chars         : {answer_chars}")
        print(f"Tool calls made      : {len(tool_calls)}")
        for i, tc in enumerate(tool_calls):
            print(f"  [{i + 1}] {tc}")
        if final_payload:
            lats = final_payload.get("latencies", {})
            print(f"generation_latency   : {lats.get('generation_latency', 'n/a')}")
            print(f"total_latency        : {lats.get('total_latency', 'n/a')}")

        if answer_chars == 0:
            print("No answer tokens were streamed.")
        return

    return None

# %% [markdown]
# ### Create a Conversation
# Before testing our endpoints we miss just one step, creating a conversation. Within EVE's framework a conversation is a multi-turn thread of user's question and model's answer, the previous messages in the conversation are passed to the model as chat history.
#
# To creagte a conversation let's use the dedicated endpoint:

# %%
def create_conversation(base_url: str, token: str) -> str:
    resp = requests.post(
        f"{base_url}/conversations",
        json={"name": "Agentic test conversation"},
        headers={"Authorization": f"Bearer {token}"},
        timeout=15,
    )
    if resp.status_code != 200:
        print(f"Create conversation failed ({resp.status_code}): {resp.text}")
    conv_id = resp.json()["id"]
    print(f"Conversation created: {conv_id}")
    return conv_id# Login to user

# %% [markdown]
# Now we have everything we need to call the endpoint

# %%
conv_id = create_conversation(BASE_URL, access_token)
payload = build_payload("Which are the coordinates of Rhodes Island?", ["geocode"])
answer = generate_agentic(payload, BASE_URL, access_token, conv_id)
print(answer['answer'])
# Out:
# Conversation created: 6a0598d6fa29b9191e606f04
# The coordinates of Rhodes Island in Greece are approximately **36.44°N latitude and 28.22°E longitude**.

# %%
answer
# Out:
# {'id': '6a0598d7fa29b9191e606f05',
#  'query': 'Which are the coordinates of Rhodes Island?',
#  'answer': 'The coordinates of Rhodes Island in Greece are approximately **36.44°N latitude and 28.22°E longitude**.',
#  'documents': [{'id': None,
#    'version': None,
#    'score': None,
#    'reranking_score': None,
#    'collection_name': None,
#    'payload': {},
#    'text': '',
#    'metadata': {}}],
#  'use_rag': True,
#  'conversation_id': '6a0598d6fa29b9191e606f04',
#  'loop_result': None,
#  'trace': [{'node': 'agent',
#    'latency_s': 1.7181966089992784,
#    'role': 'assistant',
#    'content': '',
#    'tool_calls': [{'name': 'geocode_geocode_place',
#      'args': {'place_name': 'Rhodes Island'}}]},
#   {'node': 'tools',
#    'latency_s': 14.548412389995065,
#    'role': 'tool',
#    'name': 'geocode_geocode_place',
#    'content': '[{\'type\': \'text\', \'text\': \'{"place_name": "Rhodes Island", "top_result": {"display_name": "Rhodes Island, Culion, Palawan, Mimaropa, Philippines", "bbox": "119.9489,11.7427,119.9664,11.7555", "bbox_array": [119.9489, 11.7427, 119.9664, 11.7555], "lat": 11.7490473, "lon": 119.9564625, "osm_type": "way", "class": "place", "type": "island"}, "all_results": [{"display_name": "Rhodes Island, Culion, Palawan, Mimaropa, Philippines", "bbox": "119.9489,11.7427,119.9664,11.7555", "bbox_array": [119.9489, 11.7427, 119.9664, 11.7555], "lat": 11.7490473, "lon": 119.9564625, "osm_type": "way", "class": "place", "type": "island"}, {"display_name": "Rhodes Island, Area C (Long Beach), Alberni-Clayoquot Regional District, British Columbia, Canada", "bbox": "-125.9185,49.2608,-125.9126,49.2637", "bbox_array": [-125.9185, 49.2608, -125.9126, 49.2637], "lat": 49.2622552, "lon": -125.9150267, "osm_type": "relation", "class": "place", "type": "island"}, {"display_name": "Rhodes Island, Labrador, Newfoundland and Labrador, Canada", "bbox": "-61.6718,56.5734,-61.5798,56.5949", "bbox_array": [-61.6718, 56.5734, -61.5798, 56.5949], "lat": 56.5841769, "lon": -61.6289308, "osm_type": "relation", "class": "place", "type": "island"}], "total_results": 3}\', \'id\': \'lc_7e070e78-96d4-46e5-93d9-e8e7153ab230\'}]'},
#   {'node': 'agent',
#    'latency_s': 16.666226867993828,
#    'role': 'assistant',
#    'content': 'The coordinates of Rhodes Island in Greece are approximately **36.44°N latitude and 28.22°E longitude**.'}],
#  'metadata': {'latencies': {'guardrail_latency': None,
#    'rag_decision_latency': None,
#    'query_embedding_latency': None,
#    'qdrant_retrieval_latency': None,
#    'mcp_retrieval_latency': None,
#    'reranking_latency': None,
#    'base_generation_latency': None,
#    'fallback_latency': None,
#    'hallucination_latency': None,
#    'total_latency': 17.882654359011212}}}

# %% [markdown]
# ### Tracing
#
# Tracing is fundamental to understanding what is happening at runtime. In an agentic framework, the agent can invoke multiple tools and go through several rounds of reasoning before deciding it has gathered enough information to answer the original query. The `agentic` endpoint returns the full execution trace, allowing us to inspect and understand the agent's flow.
#
# Within a trace, two types of steps can be identified:
#
# - **Agent step:** represents the execution of the EVE model. This is the entrypoint of the execution, the query is passed to the model, which then decides what action to take next.
# - **Tool step:** represents the execution of a single tool. It receives an input from the model and returns an output back to it.
#
# For each step, the trace also exposes the latency and the data produced at that stage.
#
# The trace is returned as part of the request's response. Let's inspect it:

# %%
import html
import json
from typing import Any, Dict, List, Tuple

from IPython.display import HTML, display


def _escape(s: Any) -> str:
    if s is None:
        return ""
    return html.escape(str(s), quote=True)


def _pair_tool_inputs(trace: List[Dict[str, Any]]) -> Dict[int, Any]:
    """Map each tools-step index to the args dict from the preceding agent tool_calls queue."""
    queue: List[Tuple[Any, Any]] = []
    out: Dict[int, Any] = {}
    for i, step in enumerate(trace):
        node = (step.get("node") or "").lower()
        if node == "agent":
            for tc in step.get("tool_calls") or []:
                queue.append((tc.get("name"), tc.get("args")))
        elif node == "tools":
            name = step.get("name")
            args = None
            for j, (qn, qa) in enumerate(queue):
                if qn == name:
                    args = qa
                    queue.pop(j)
                    break
            if args is None and queue:
                args = queue.pop(0)[1]
            out[i] = args
    return out


# ── Inline-style constants (no <style> block — GitHub-safe) ──────────────────
_STEP_STYLES = {
    "agent": {
        "bg": "#f5f3ff",
        "rail": "#7c3aed",
        "pill_bg": "#ede9fe",
        "pill_fg": "#5b21b6",
        "title": "EVE Agent Step",
        "sub": "Plans the next action or writes the final reply.",
        "gantt": "#7c3aed",
    },
    "tools": {
        "bg": "#ecfeff",
        "rail": "#0891b2",
        "pill_bg": "#cffafe",
        "pill_fg": "#155e75",
        "title": "Tool Execution",
        "sub": "Runs one tool and returns its payload.",
        "gantt": "#0891b2",
    },
}
_DEFAULT_STYLE = {
    "bg": "#f8fafc", "rail": "#64748b",
    "pill_bg": "#f1f5f9", "pill_fg": "#475569",
    "title": "Step", "sub": "", "gantt": "#94a3b8",
}

# Reusable inline style strings
_PRE  = "margin:0;padding:0.45rem 0.65rem;background:#f8fafc;border:1px solid #e2e8f0;border-radius:0 6px 6px 0;font-size:0.7rem;line-height:1.5;white-space:pre-wrap;word-break:break-word;color:#334155;font-family:ui-monospace,'SFMono-Regular',Consolas,monospace"
_LBL  = "font-size:0.65rem;text-transform:uppercase;letter-spacing:0.07em;color:#64748b;display:block;margin:0.55rem 0 0.2rem"
_CODE = "background:#f1f5f9;padding:1px 5px;border-radius:4px;font-size:0.78rem;color:#1e293b;font-family:ui-monospace,'SFMono-Regular',Consolas,monospace"


def visualize_agent_trace(result: dict) -> None:
    """Render the EVE agent trace — light theme, inline styles, GitHub-compatible."""
    trace  = result.get("trace") or []
    query  = result.get("query", "")
    meta   = result.get("metadata") or {}
    lats   = (meta.get("latencies") or {})
    total_wall = float(lats.get("total_latency") or 0) or sum(
        float(s.get("latency_s") or 0) for s in trace
    ) or 1e-9

    if not trace:
        display(HTML("<p><em>No trace in this result.</em></p>"))
        return

    tool_inputs = _pair_tool_inputs(trace)

    # ── Gantt bar ─────────────────────────────────────────────────────────────
    gantt_segs, t0 = [], 0.0
    for step in trace:
        lat   = float(step.get("latency_s") or 0)
        left  = 100 * t0 / total_wall
        width = max(0.6, 100 * lat / total_wall)
        s     = _STEP_STYLES.get((step.get("node") or "").lower(), _DEFAULT_STYLE)
        name  = step.get("name") or ((step.get("tool_calls") or [{}])[0].get("name")) or step.get("node", "?")
        tip   = _escape(f"{name} · {lat:.1f}s")
        gantt_segs.append(
            f'<div title="{tip}" style="position:absolute;top:4px;bottom:4px;'
            f'left:{left:.2f}%;width:{width:.2f}%;background:{s["gantt"]};'
            f'border-radius:5px;opacity:0.8"></div>'
        )
        t0 += lat

    gantt_html = (
        '<div style="display:flex;justify-content:space-between;font-size:0.7rem;color:#94a3b8;margin-bottom:0.2rem">'
        f'<span>Timeline (by step latency)</span><span>{total_wall:.1f}s total</span></div>'
        '<div style="position:relative;height:26px;background:#f1f5f9;border-radius:7px;'
        'border:1px solid #e2e8f0;overflow:hidden;margin-bottom:1rem">'
        + "".join(gantt_segs) + "</div>"
    )

    # ── Step cards ────────────────────────────────────────────────────────────
    cards_html, cumulative = [], 0.0

    for i, step in enumerate(trace):
        node = (step.get("node") or "step").lower()
        s    = _STEP_STYLES.get(node, _DEFAULT_STYLE)
        lat  = float(step.get("latency_s") or 0)
        cumulative += lat
        role = _escape(step.get("role", ""))

        body_parts: list[str] = []

        if node == "agent":
            tcalls = step.get("tool_calls") or []
            if tcalls:
                names = ", ".join(f'<code style="{_CODE}">{_escape(tc.get("name","?"))}</code>' for tc in tcalls)
                body_parts.append(
                    f'<p style="margin:0.25rem 0;font-size:0.81rem;color:#475569">'
                    f'Requesting tool(s): {names}</p>'
                )
            content = (step.get("content") or "").strip()
            if content:
                body_parts.append(
                    f'<details style="margin-top:0.4rem"><summary style="cursor:pointer;'
                    f'font-size:0.78rem;color:#6d28d9">Assistant message ({len(content)} chars)</summary>'
                    f'<pre style="{_PRE};margin-top:0.3rem;border-left:3px solid #a78bfa">{_escape(content)}</pre>'
                    f'</details>'
                )
            if not body_parts:
                body_parts.append('<p style="margin:0.2rem 0;font-size:0.81rem;color:#94a3b8">Deciding next action…</p>')

        elif node == "tools":
            tname = _escape(step.get("name", "tool"))
            body_parts.append(
                f'<p style="margin:0 0 0.3rem;font-size:0.84rem;color:#1e293b">Tool: '
                f'<code style="background:#cffafe;color:#155e75;padding:2px 8px;'
                f'border-radius:5px;font-size:0.8rem;font-family:ui-monospace,monospace">{tname}</code></p>'
            )
            inp = tool_inputs.get(i)
            if inp is not None:
                try:
                    inp_txt = json.dumps(inp, indent=2, ensure_ascii=False)
                except (TypeError, ValueError):
                    inp_txt = str(inp)
                body_parts.append(
                    f'<span style="{_LBL}">Input — arguments passed to the tool</span>'
                    f'<pre style="{_PRE};border-left:3px solid #7c3aed">{_escape(inp_txt)}</pre>'
                )
            raw = step.get("content")
            out_txt = raw if isinstance(raw, str) else json.dumps(raw, indent=2, ensure_ascii=False, default=str)
            body_parts.append(
                f'<span style="{_LBL}">Output — value returned to the model</span>'
                f'<pre style="{_PRE};border-left:3px solid #0891b2">{_escape(out_txt)}</pre>'
            )
        else:
            body_parts.append(
                f'<pre style="{_PRE}">{_escape(json.dumps(step, indent=2, default=str))}</pre>'
            )

        role_html = (
            f'<span style="font-size:0.74rem;color:#64748b">{role}</span>' if role else ""
        )
        card = (
            f'<div style="display:flex;background:{s["bg"]};border-radius:10px;'
            f'overflow:hidden;border:1px solid #e2e8f0;margin-bottom:0.6rem">'
            f'<div style="width:5px;background:{s["rail"]};flex-shrink:0"></div>'
            f'<div style="flex:1;padding:0.65rem 0.9rem 0.75rem;min-width:0">'
            # header row
            f'<div style="display:flex;flex-wrap:wrap;align-items:center;gap:0.4rem;margin-bottom:0.15rem">'
            f'<span style="font-size:0.63rem;text-transform:uppercase;letter-spacing:0.08em;color:#94a3b8;font-weight:600">Step {i+1}</span>'
            f'<span style="font-size:0.66rem;font-weight:600;padding:0.1rem 0.45rem;border-radius:999px;'
            f'border:1px solid {s["rail"]};background:{s["pill_bg"]};color:{s["pill_fg"]};'
            f'text-transform:uppercase;letter-spacing:0.04em">{_escape(node)}</span>'
            f'{role_html}'
            f'<span style="margin-left:auto;font-weight:700;color:#b45309;font-size:0.8rem">{lat:.2f}s</span>'
            f'</div>'
            # title + subtitle
            f'<div style="font-size:0.93rem;font-weight:600;color:#1e293b;margin:0 0 0.1rem">{s["title"]}</div>'
            f'<div style="font-size:0.77rem;color:#64748b;margin-bottom:0.4rem">{s["sub"]}</div>'
            # body
            + "".join(body_parts)
            # footer
            + f'<div style="margin-top:0.4rem;font-size:0.67rem;color:#94a3b8;'
            f'border-top:1px dashed #e2e8f0;padding-top:0.3rem">≈ {cumulative:.2f}s elapsed in trace</div>'
            f'</div></div>'
        )
        cards_html.append(card)

    # ── Legend ────────────────────────────────────────────────────────────────
    legend_html = (
        '<div style="display:flex;gap:1rem;flex-wrap:wrap;margin-bottom:0.75rem">'
    )
    for label, s in _STEP_STYLES.items():
        legend_html += (
            f'<span style="display:inline-flex;align-items:center;gap:0.3rem;'
            f'font-size:0.72rem;color:#475569">'
            f'<span style="display:inline-block;width:10px;height:10px;border-radius:3px;'
            f'background:{s["rail"]}"></span>{label}</span>'
        )
    legend_html += "</div>"

    html_doc = (
        '<div style="font-family:ui-sans-serif,system-ui,-apple-system,\'Segoe UI\',Roboto,Helvetica,Arial;'
        'background:#ffffff;color:#1e293b;border-radius:12px;padding:1.1rem 1.4rem 1.3rem;'
        'margin:0.5rem 0 1rem;border:1px solid #e2e8f0;box-shadow:0 1px 6px rgba(0,0,0,0.06)">'
        '<div style="font-size:1.05rem;font-weight:700;color:#1e293b;margin-bottom:0.2rem">Agent execution trace</div>'
        f'<p style="margin:0 0 0.85rem;font-size:0.84rem;color:#64748b">'
        f'<strong style="color:#1e293b">Query</strong> — {_escape(query)}</p>'
        + legend_html
        + gantt_html
        + "".join(cards_html)
        + "</div>"
    )
    display(HTML(html_doc))


# Visualize the last agentic response
visualize_agent_trace(answer)
# Out:
# <div style="font-family:ui-sans-serif,system-ui,-apple-system,'Segoe UI',Roboto,Helvetica,Arial;background:#ffffff;color:#1e293b;border-radius:12px;padding:1.1rem 1.4rem 1.3rem;margin:0.5rem 0 1rem;border:1px solid #e2e8f0;box-shadow:0 1px 6px rgba(0,0,0,0.06)"><div style="font-size:1.05rem;font-weight:700;color:#1e293b;margin-bottom:0.2rem">Agent execution trace</div><p style="margin:0 0 0.85rem;font-size:0.84rem;color:#64748b"><strong style="color:#1e293b">Query</strong> — Which are the coordinates of Rhodes Island?</p><div style="display:flex;gap:1rem;flex-wrap:wrap;margin-bottom:0.75rem"><span style="display:inline-flex;align-items:center;gap:0.3rem;font-size:0.72rem;color:#475569"><span style="display:inline-block;width:10px;height:10px;border-radius:3px;background:#7c3aed"></span>agent</span><span style="display:inline-flex;align-items:center;gap:0.3rem;font-size:0.72rem;color:#475569"><span style="display:inline-block;width:10px;height:10px;border-radius:3px;background:#0891b2"></span>tools</span></div><div style="display:flex;justify-content:space-between;font-size:0.7rem;color:#94a3b8;margin-bottom:0.2rem"><span>Timeline (by step latency)</span><span>17.9s total</span></div><div style="position:relative;height:26px;background:#f1f5f9;border-radius:7px;border:1px solid #e2e8f0;overflow:hidden;margin-bottom:1rem"><div title="geocode_geocode_place · 1.7s" style="position:absolute;top:4px;bottom:4px;left:0.00%;width:9.61%;background:#7c3aed;border-radius:5px;opacity:0.8"></div><div title="geocode_geocode_place · 14.5s" style="position:absolute;top:4px;bottom:4px;left:9.61%;width:81.35%;background:#0891b2;border-radius:5px;opacity:0.8"></div><div title="agent · 16.7s" style="position:absolute;top:4px;bottom:4px;left:90.96%;width:93.20%;background:#7c3aed;border-radius:5px;opacity:0.8"></div></div><div style="display:flex;background:#f5f3ff;border-radius:10px;overflow:hidden;border:1px solid #e2e8f0;margin-bottom:0.6rem"><div style="width:5px;background:#7c3aed;flex-shrink:0"></div><div style="flex:1;padding:0.65rem 0.9rem 0.75rem;min-width:0"><div style="display:flex;flex-wrap:wrap;align-items:center;gap:0.4rem;margin-bottom:0.15rem"><span style="font-size:0.63rem;text-transform:uppercase;letter-spacing:0.08em;color:#94a3b8;font-weight:600">Step 1</span><span style="font-size:0.66rem;font-weight:600;padding:0.1rem 0.45rem;border-radius:999px;border:1px solid #7c3aed;background:#ede9fe;color:#5b21b6;text-transform:uppercase;letter-spacing:0.04em">agent</span><span style="font-size:0.74rem;color:#64748b">assistant</span><span style="margin-left:auto;font-weight:700;color:#b45309;font-size:0.8rem">1.72s</span></div><div style="font-size:0.93rem;font-weight:600;color:#1e293b;margin:0 0 0.1rem">EVE Agent Step</div><div style="font-size:0.77rem;color:#64748b;margin-bottom:0.4rem">Plans the next action or writes the final reply.</div><p style="margin:0.25rem 0;font-size:0.81rem;color:#475569">Requesting tool(s): <code style="background:#f1f5f9;padding:1px 5px;border-radius:4px;font-size:0.78rem;color:#1e293b;font-family:ui-monospace,'SFMono-Regular',Consolas,monospace">geocode_geocode_place</code></p><div style="margin-top:0.4rem;font-size:0.67rem;color:#94a3b8;border-top:1px dashed #e2e8f0;padding-top:0.3rem">≈ 1.72s elapsed in trace</div></div></div><div style="display:flex;background:#ecfeff;border-radius:10px;overflow:hidden;border:1px solid #e2e8f0;margin-bottom:0.6rem"><div style="width:5px;background:#0891b2;flex-shrink:0"></div><div style="flex:1;padding:0.65rem 0.9rem 0.75rem;min-width:0"><div style="display:flex;flex-wrap:wrap;align-items:center;gap:0.4rem;margin-bottom:0.15rem"><span style="font-size:0.63rem;text-transform:uppercase;letter-spacing:0.08em;color:#94a3b8;font-weight:600">Step 2</span><span style="font-size:0.66rem;font-weight:600;padding:0.1rem 0.45rem;border-radius:999px;border:1px solid #0891b2;background:#cffafe;color:#155e75;text-transform:uppercase;letter-spacing:0.04em">tools</span><span style="font ...
#   &quot;place_name&quot;: &quot;Rhodes Island&quot;
# }</pre><span style="font-size:0.65rem;text-transform:uppercase;letter-spacing:0.07em;color:#64748b;display:block;margin:0.55rem 0 0.2rem">Output — value returned to the model</span><pre style="margin:0;padding:0.45rem 0.65rem;background:#f8fafc;border:1px solid #e2e8f0;border-radius:0 6px 6px 0;font-size:0.7rem;line-height:1.5;white-space:pre-wrap;word-break:break-word;color:#334155;font-family:ui-monospace,'SFMono-Regular',Consolas,monospace;border-left:3px solid #0891b2">[{&#x27;type&#x27;: &#x27;text&#x27;, &#x27;text&#x27;: &#x27;{&quot;place_name&quot;: &quot;Rhodes Island&quot;, &quot;top_result&quot;: {&quot;display_name&quot;: &quot;Rhodes Island, Culion, Palawan, Mimaropa, Philippines&quot;, &quot;bbox&quot;: &quot;119.9489,11.7427,119.9664,11.7555&quot;, &quot;bbox_array&quot;: [119.9489, 11.7427, 119.9664, 11.7555], &quot;lat&quot;: 11.7490473, &quot;lon&quot;: 119.9564625, &quot;osm_type&quot;: &quot;way&quot;, &quot;class&quot;: &quot;place&quot;, &quot;type&quot;: &quot;island&quot;}, &quot;all_results&quot;: [{&quot;display_name&quot;: &quot;Rhodes Island, Culion, Palawan, Mimaropa, Philippines&quot;, &quot;bbox&quot;: &quot;119.9489,11.7427,119.9664,11.7555&quot;, &quot;bbox_array&quot;: [119.9489, 11.7427, 119.9664, 11.7555], &quot;lat&quot;: 11.7490473, &quot;lon&quot;: 119.9564625, &quot;osm_type&quot;: &quot;way&quot;, &quot;class&quot;: &quot;place&quot;, &quot;type&quot;: &quot;island&quot;}, {&quot;display_name&quot;: &quot;Rhodes Island, Area C (Long Beach), Alberni-Clayoquot Regional District, British Columbia, Canada&quot;, &quot;bbox&quot;: &quot;-125.9185,49.2608,-125.9126,49.2637&quot;, &quot;bbox_array&quot;: [-125.9185, 49.2608, -125.9126, 49.2637], &quot;lat&quot;: 49.2622552, &quot;lon&quot;: -125.9150267, &quot;osm_type&quot;: &quot;relation&quot;, &quot;class&quot;: &quot;place&quot;, &quot;type&quot;: &quot;island&quot;}, {&quot;display_name&quot;: &quot;Rhodes Island, Labrador, Newfoundland and Labrador, Canada&quot;, &quot;bbox&quot;: &quot;-61.6718,56.5734,-61.5798,56.5949&quot;, &quot;bbox_array&quot;: [-61.6718, 56.5734, -61.5798, 56.5949], &quot;lat&quot;: 56.5841769, &quot;lon&quot;: -61.6289308, &quot;osm_type&quot;: &quot;relation&quot;, &quot;class&quot;: &quot;place&quot;, &quot;type&quot;: &quot;island&quot;}], &quot;total_results&quot;: 3}&#x27;, &#x27;id&#x27;: &#x27;lc_7e070e78-96d4-46e5-93d9-e8e7153ab230&#x27;}]</pre><div style="margin-top:0.4rem;font-size:0.67rem;color:#94a3b8;border-top:1px dashed #e2e8f0;padding-top:0.3rem">≈ 16.27s elapsed in trace</div></div></div><div style="display:flex;background:#f5f3ff;border-radius:10px;overflow:hidden;border:1px solid #e2e8f0;margin-bottom:0.6rem"><div style="width:5px;background:#7c3aed;flex-shrink:0"></div><div style="flex:1;padding:0.65rem 0.9rem 0.75rem;min-width:0"><div style="display:flex;flex-wrap:wrap;align-items:center;gap:0.4rem;margin-bot

# %% [markdown]
# # Conclusion — What We Built and Where to Go Next
#
# ## What We Learned
#
# We moved from **concepts** (domain LLMs, tools, ReAct agents) to **working integrations**: turning real geospatial services into callable units, exposing them through **MCP**, registering them in **EVE's Tool Registry**, and driving them from **EVE's agentic API** with inspectable **traces**.
#
# Along the way, this notebook covered:
#
# 1. **From services to tools**: Why small, composable connectors beat monolithic pipelines; how [Nominatim](https://nominatim.openstreetmap.org/) turns place names into bounding boxes that downstream EO services expect; design rules (clear names, simple inputs, structured JSON output).
# 2. **MCP**: The [Model Context Protocol](https://modelcontextprotocol.io/) as a standard way for models to discover and invoke tools; [FastMCP](https://gofastmcp.com/) to generate schemas and run a server over **HTTP** (or stdio for desktop clients).
# 3. **EVE Tool Registry**: Community and ESA Φ-lab **MCP servers** (for example `effis`, `eve_retrieval`), authentication, listing servers, and calling a deployed tool from the platform.
# 4. **Agentic EVE**: The [ReAct](https://arxiv.org/abs/2210.03629) loop (reason → act with a tool → observe) implemented in practice via EVE's **LangChain / LangGraph** stack; experimental endpoints `generate-agentic` and `stream-generate-agentic` with `public_mcp_servers` to scope which tools the model may use.
# 5. **Tracing**: Reading the returned **trace** (agent steps vs tool steps, latencies, arguments) so you can debug ambiguous queries (for example disambiguating "Attica") and verify tool use.
#
# The recurring idea: **capabilities** are fixed in the tool layer; **orchestration** is chosen at runtime by the model, conditioned on your question and the tool descriptions.
#
#
# ## Earth Observation services you could turn into tools
#
# Each row is a **single-responsibility** tool candidate: one function, one API slice, JSON in and out, the same pattern as geocoding.
#
# | Capability | Example service | Why it fits an agent |
# |---|---|---|
# | **Catalogue search** | [Copernicus Data Space Ecosystem — STAC / OData](https://documentation.dataspace.copernicus.eu/APIs.html) | Find Sentinel scenes by bbox, time, cloud cover; return STAC items as JSON for the model to cite |
# | **Atmosphere** | [Copernicus Atmosphere Monitoring Service (CAMS)](https://atmosphere.copernicus.eu/) | Aerosol, CO, fire emissions, context for smoke plumes and air quality next to thermal anomalies |
# | **Land cover** | [ESA WorldCover](https://esa-worldcover.org/en) | Stratify burns, crops, or floods by land-cover class inside a region |
# | **Land monitoring** | [Copernicus Land Monitoring Service (CLMS)](https://land.copernicus.eu/) | Vegetation properties, water bodies, imperviousness, alternatives to hand-rolled indices |
# | **Processing graphs** | [openEO](https://openeo.org/) | Portable processing; agent picks a predefined graph or parameters, backend runs the cube |
# | **Planetary-scale cubes** | [Google Earth Engine](https://earthengine.google.com/) | Time series, reducers, and catalog queries via the official Python/REST APIs |
# | **NASA granules** | [NASA Earthdata / CMR](https://www.earthdata.nasa.gov/) | Search and order for MODIS, VIIRS, GPM, etc., complementary to Copernicus |
# | **Weather context** | [Open-Meteo](https://open-meteo.com/) | Free historical and forecast weather (wind, temperature, precipitation) keyed by coordinates and time |
# | **Marine & altimetry** | [CMEMS](https://marine.copernicus.eu/) (Copernicus Marine) | Ocean colour, SST, waves, for coastal events and storms |
# | **Elevation** | [Open-Elevation](https://open-elevation.com/) or [Copernicus DEM](https://spacedata.copernicus.eu/collections/copernicus-digital-elevation-model) | Terrain context for shadows, flooding, and plume channeling |
#
# The pattern does not change: wrap the API, return **structured** results, write a **precise docstring**, register the server, the agent learns the rest from the tool schema.
#
# ## Interesting tool and MCP repositories
#
# | Repository | Role |
# |---|---|
# | [github.com/eve-esa/tools](https://github.com/eve-esa/tools) | **EVE Tool Registry** — official MCP servers, CI deploy, contribution guide |
# | [github.com/nasa/earthdata-mcp](https://github.com/nasa/earthdata-mcp) | NASA **Earthdata** oriented MCP tooling (discovery and workflows) |
# | [github.com/IBM/chuk-mcp-stac](https://github.com/IBM/chuk-mcp-stac) | **STAC**-centric MCP — scene search, indices, compositing patterns |
# | [github.com/wb1016/copernicus-mcp](https://github.com/wb1016/copernicus-mcp) | **Copernicus** MCP for ESA **OData** catalogue access (Sentinel and related products; search and download workflows) |
# | [github.com/aliafsahnoudeh/wildfire-mcp-server](https://github.com/aliafsahnoudeh/wildfire-mcp-server) | **Wildfire** MCP — NASA FIRMS hotspots, weather, air pollution, reverse geocoding, GEE land-cover fuel cues *(custom license: evaluation/non-production unless approved)* |
# | [github.com/armaasinghn/geosight-mcp](https://github.com/armaasinghn/geosight-mcp) | **GeoSight** — satellite imagery tools (NDVI, NDWI, land cover, change detection, reports) via Sentinel Hub and related stacks |
# | [pulsemcp.com — mahdin75/geoserver](https://www.pulsemcp.com/servers/mahdin75-geoserver) | **GeoServer**-oriented MCP entry on the [Pulse MCP](https://www.pulsemcp.com/) server directory |
# | [pulsemcp.com/servers?q=earth](https://www.pulsemcp.com/servers?q=earth) | **Pulse MCP** browse: pre-filtered search for **Earth** / geospatial-related MCP servers |
# | [github.com/punkpeye/awesome-mcp-servers](https://github.com/punkpeye/awesome-mcp-servers) | Large curated list of MCP servers by category |
# | [github.com/langchain-ai/langchain-mcp-adapters](https://github.com/langchain-ai/langchain-mcp-adapters) | Bridge **MCP** tools into **LangChain** agents |
#
# ## Useful links by category
#
# **Agents and orchestration**
#
# - [LangGraph](https://langchain-ai.github.io/langgraph/) — stateful, graph-based agents (ReAct and beyond)
# - [LangChain](https://python.langchain.com/docs/introduction/) — tools, models, and composable chains
# - [ReAct (Yao et al., 2023)](https://arxiv.org/abs/2210.03629) — reasoning + acting pattern cited in this notebook
#
# **MCP and server implementation**
#
# - [Model Context Protocol](https://modelcontextprotocol.io/) — specification and concepts
# - [FastMCP](https://gofastmcp.com/) — Python server framework used here
# - [Hugging Face MCP course (Unit 1)](https://huggingface.co/learn/mcp-course/unit1/key-concepts) — gentle introduction to hosts, clients, and servers
#
# **EVE, model, and platform**
#
# - [EVE (Earth Virtual Expert) on Hugging Face](https://huggingface.co/eve-esa) — open-weight EO-focused model (Apache 2.0)
# - [EVE staging agentic API docs](https://staging-agentic-api.eve-chat.chat/docs) — REST surface including agentic endpoints *(staging URL as used in the notebook; production may differ)*
#
# **EO data and standards (background for new tools)**
#
# - [Copernicus Data Space Ecosystem](https://dataspace.copernicus.eu/) — Sentinel catalogues and APIs
# - [STAC specification](https://stacspec.org/) — spatiotemporal metadata interchange
# - [EFFIS](https://effis.jrc.ec.europa.eu/) — European fire information (also referenced in-toolkit servers)
#
# **Evaluation (when you want to measure agent quality)**
#
# - [GAIA (Mialon et al., 2023)](https://arxiv.org/abs/2311.12983) — real-world multi-step tasks
# - [GEO-Bench (Lacoste et al., 2023)](https://arxiv.org/abs/2306.03831) — benchmarks for models on EO-style data
#
# **Recent EO + agent pointers (optional reading)**
#
# - [OpenEarthAgent (Shabbir et al., 2026)](https://arxiv.org/abs/2602.17665) — tool-augmented agents for EO tasks
# - [Earth-Agent (Feng et al., 2025)](https://arxiv.org/abs/2509.23141) — general-purpose EO agent framing
#
# ## What is next for the platform
#
# EVE's roadmap naturally includes richer **multi-agent** setups, more **MCP servers** from the community, tighter links to **processing** (openEO, cloud-native Geo), and mature **private** MCP attachments per user. Experimental **agentic** endpoints will evolve; keep an eye on API docs and changelog when you ship workflows.
#
# ---
#
# ## Your turn: create tools and contribute
#
# **Now it is your turn.** Pick one EO or geospatial API you rely on in daily work, implement a **small** FastMCP server (one job per tool, structured JSON, descriptive docstrings), and open a pull request to the official registry: [github.com/eve-esa/tools](https://github.com/eve-esa/tools). Follow [CONTRIBUTING.md](https://github.com/eve-esa/tools/blob/main/CONTRIBUTING.md) for layout, `requirements.txt`, secrets hygiene, and CI expectations.
#
# Every new tool enlarges what **every** EVE user can ask without new prompt engineering: you are not only shipping code, you are extending the **shared affordances** of Earth-observation agents. Contribute early, iterate with traces in hand, and help define the open tool layer for agentic EO.
